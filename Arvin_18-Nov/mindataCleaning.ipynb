# %%
import pandas as pd
import json
import os
from collections import defaultdict

os.chdir('C:\\Users\\arvgoyal\Python Codes\IRE Project\Data Cleaning\data')

# %%
#df = pd.read_json('combined_minerals.json')
with open('mindat.json') as webMinJsn:
    data = json.load(webMinJsn)
data
# Out:
# {'Torreyite': {'Formula': '(Mg,Mn2+)7◻2Mn2+2Zn4(SO4)2(OH)22 · 8H2O',
#   'Colour': 'Rarely colourless, white, usually light brown with a red gray tint, rarely very pale blue gray; colourless in transmitted light.',
#   'Lustre': 'Vitreous, Sub-Vitreous, Pearly, Dull',
#   'Hardness': ['3', '3 on Mohs scale'],
#   'Specific Gravity': '2.665',
#   'Crystal System': 'Monoclinic',
#   'Name': 'Named in 1949 by Joan Prewitt-Hopkins in honor of John Torrey [August 15, 1796 New York, New York, USA - March 10, 1873 New York, New York, USA], American medical doctor, botanist, mineralogist and chemist; a founding member of the New York Lyceum of Natural History and its first Curator, and subsequently its President. He was a Professor of Chemistry, an author, and was appointed U.S. Assayer for the new U.S. mint in New York City in 1853. He studied the minerals of the Franklin deposits in New Jersey. Originally called "delta-mooreite", but renamed when it was discovered that the two species have a different structure.',
#   'Type Locality': 'ⓘ Sterling Mine, Sterling Hill, Ogdensburg, Franklin Mining District, Sussex County, New Jersey, USA',
#   'Isostructural with': 'Lawsonbauerite',
#   'IMA status': "Approved, 'Grandfathered' (first described prior to 1959)",
#   'Strunz 8th ed.': '6/D.04-20',
#   'Nickel-Strunz 10th (pending) ed.': '7.DD.407 : SULFATES (selenates, tellurates, chromates, molybdates, wolframates)D : Sulfates (selenates, etc.) with additional anions, with H2OD : With only medium-sized cations; sheets of edge-sharing octahedra',
#   'Dana 8th ed.': '31.1.4.131 : HYDRATED SULFATES CONTAINING HYDROXYL OR HALOGEN1 : (AB)m(XO4)pZq·xH2O, where m:p > 6:1',
#   "Hey's CIM Ref.": '25.9.1125 : Sulphates9 : Sulphates of Mn',
#   'Transparency': 'Transparent, Translucent',
#   'Comment': ['Micaceous is an accurate description of the cleavage except that the folia are not broad as in a platy mica, but the cleavage follows the rod-like habit common to the mineral.',
#    'Frequently dull',
#    'May be tan to light brown as a surface coating when slightly oxidized.'],
#   'Streak': 'White to colorless',
#   'Tenacity': 'Brittle',
#   'Cleavage': 'Distinct/GoodOn {010}, good.',
#   'Fracture': 'Micaceous',
#   'Density': '2.665 g/cm3 (Measured) \xa0\xa0\xa02.65 g/cm3 (Calculated)',
#   'Type': 'Biaxial (-)',
#   'RI values': ' nα = 1.570 nβ = 1.584 nγ = 1.585',
#   '2V': 'Measured: 40° , Calculated: 28° ',
#   'Birefringence': '0.015',
#   'Surface Relief': 'Moderate',
#   'Dispersion': 'r > v',
#   'Pleochroism': 'Non-pleochroic',
#   'Comments': ['Refractive index is decidedly higher than mooreite',
#    'ICDD 33-874; pattern superficially resembles that of mooreite, but with a slight shift to larger d spacings. There are also mismatching d values when compared to mooreite.'],
#   'IMA Formula': 'Mg9Zn4(SO4)2(OH)22 · 8H2O',
#   'Type Locality': "ⓘ Solnechnogorsk Village (Kuru-Uzen'), Alushta, Crimea, Russia",
#   'IMA status': "Approved, 'Grandfathered' (first described prior to 1959)",
#   'First published': '1963',
#   'Strunz 8th ed.': '8/H.18-50',
#   'Nickel-Strunz 10th (pending) ed.': '9.EC.609 : SILICATES (Germanates)E : PhyllosilicatesC : Phyllosilicates with mica sheets, composed of tetrahedral and octahedral nets',
#   'Dana 8th ed.': '71.4.2.471 : PHYLLOSILICATES Sheets of Six-Membered Rings4 : Sheets of 6-membered rings interlayered 1:1, 2:1, and octahedra',
#   'Transparency': 'Translucent',
#   'Cleavage': 'Perfect{001}',
#   'Density': '2.83 g/cm3 (Measured) \xa0\xa0\xa0',
#   'Type': 'Biaxial (-)',
#   'RI values': ' nα = 1.542 - 1.564 nβ = 1.570 nγ = 1.548 - 1.574',
#   '2V': 'Measured: 59° ',
#   'Surface Relief': 'Low',
#   'Dispersion': 'none',
#   'IMA Formula': 'Na0.5(Al,Mg)6(Si,Al)8O18(OH)12 · 5H2O',
#   'Elements listed': 'Al, H, Mg, Na, O, Si - search for minerals with similar chemistry',
#   'Common Impurities': 'Fe,Mg,Ca,Li',
#   'Class (H-M)': '2 - Sphenoidal',
#   'Space Group': 'B2 ',
#   'Cell Parameters': 'a = 5.17 Å, b = 8.97 Å, c = 24.2 Åβ = 94°',
#   'Ratio': 'a:b:c = 0.576 : 1 : 2.698',
#   'Unit Cell V': '1,119.54 Å³ (Calculated from Unit Cell)',
#   'Morphology': 'Microscopically crystalline',
#   'Health Risks': 'No information on health risks for this material has been entered into the database. You should always treat mineral specimens with care.',
#   'Reference List': 'Sort by Year (asc) | by Year (desc) | by Author (A-Z) | by Author (Z-A)Frank-Kamenetskii, V.A., Logvinenko, N.V., Drits, V.A. (1963) A dioctahedral mixed-layer clay mineral - tosudite. Zapiski Vserossijskogo Mineralogicheskogo Obshchestva: 92: 560-565. (in Russian)Fleischer, M. (1964) New mineral names. American Mineralogist: 49: 816-821.Shimoda, S. (1969) New data for tosudite. Clays and Clay Minerals: 17: 179-184.Fleischer, M. (1970) New mineral names. American Mineralogist: 55: 1067-1073.Nishiyama, T., Shimoda, S., Shimosaka, K., Kanaoka, S. (1975) Lithium-bearing tosudite. Clays and Clay Minerals: 23: 337-342.Fin\'ko, V.I., Drits, V.A., Slonimskaya, N.V. (1977) Lithium tosudite from hydrothermal altered rocks of Lover Preamurie, - Izvestiya AN SSSR, ser. geologicheskaya: 12: 73-78. (in Russian)Bailey, S.W. (1982) Nomenclature for regular interstratifications. American Mineralogist: 67: 394-398.Kartashov, P.M. (1989) On Li-bearing Alushtite from Crimea and its position in the tosudite group. Novye Dannye o Mineralah, Moscow, "Nauka": 36: 67-83. (in Russian)\n',
#   'mindat.org URL': 'https://www.mindat.org/min-4001.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Tosudite on Google\nLook for Tosudite images on Google',
#   'External Links': 'Look for Tosudite on Webmineral\nLook for Tosudite on Wikipedia\nLook for Tosudite on Mineralien Atlas\nRaman and XRD data at RRUFF project\nReferences and PDF downloads at RRUFF project\nAmerican Mineralogist Crystal Structure Database\nHandbook of Mineralogy page PDF',
#   'Mineral Dealers': 'Buy rare minerals from Excalibur MineralsBuy from McDougall MineralsBuy from David K Joyce mineralsFine Minerals from Weinrich Minerals, Inc.Fabre Minerals - search for Tosudite specimensTop quality minerals from Kristalle of CaliforniaQuality Minerals at Fair PricesBlue Gems Australian & InternationalWilensky Exquisite MineralsHigh-end worldwide specimens & outstanding customer serviceWendel Minerals - Auction & Shop'},
#  'Tounkite': {'Formula': '(Na,Ca,K)8(Al6Si6O24)(SO4)2Cl · H2O',
#   'Colour': 'Green to yellowish-green, glass-green with a yellowish or gray tint',
#   'Lustre': 'Vitreous',
#   'Hardness': ['5 - 5½ on Mohs scale', '5 - 5½'],
#   'Crystal System': 'Hexagonal',
#   'Member of': 'Cancrinite Group > Feldspathoid Group',
#   'Name': 'Named after its discovery locality, Tounka Valley, Baikal region, Russia.',
#   'Co-Type Localities': 'ⓘ Malo-Bystrinskoe lazurite deposit, Malaya Bystraya River Valley, Slyudyanka (Sludyanka), Lake Baikal area, Irkutsk Oblast, Russiaⓘ Tultui lazurite deposit, Malaya Bystraya River Valley, Slyudyanka (Sludyanka), Lake Baikal area, Irkutsk Oblast, Russia',
#   'Dimorph of': 'UM2004-48-SiO:AlClCaNaS',
#   'IMA status': 'Approved',
#   'Approval year': '1990',
#   'First published': '1992',
#   'Strunz 8th ed.': '8/J.09-55',
#   'Nickel-Strunz 10th (pending) ed.': '9.FB.059 : SILICATES (Germanates)F : Tektosilicates without zeolitic H2OB : Tektosilicates with additional anions',
#   'Dana 8th ed.': '76.2.5.1476 : TECTOSILICATES Al-Si Framework2 : Al-Si Framework Feldspathoids and related species',
#   'Streak': 'White',
#   'Cleavage': 'Distinct/Good',
#   'Type': 'Uniaxial (+)',
#   'RI values': ' nω = 1.528 nε = 1.543',
#   'Surface Relief': 'Low',
#   'IMA Formula': '(Na,Ca,K)8(Si6Al6)O24(SO4)2Cl · 0.5H2O',
#   'Elements listed': 'Al, Ca, Cl, H, K, Na, O, S, Si - search for minerals with similar chemistry',
#   'Cell Parameters': 'a = 12.84 Å, c = 32.23 Å',
#   'Ratio': 'a:c = 1 : 2.51',
#   'Unit Cell V': '4,601.73 Å³ (Calculated from Unit Cell)',
#   'Reference': 'Ivanov, V.G., Sapozhnikov, A.N., Piskunova, L.F., Kashayev, A.A. (1992) Tounkite (Na,Ca,K)8(Al6Si6O24)(SO4)2Cl·H2O- a new cancrinite-like mineral. Zapiski Vserossijskogo Mineralogicheskogo Obshchestva: 121(2): 92-95.',
#   'Download': 'https://rruff.info/rruff_1.0/uploads/ZVMO121N2_92.pdf',
#   'Health Risks': 'No information on health risks for this material has been entered into the database. You should always treat mineral specimens with care.',
#   'Reference List': 'Sort by Year (asc) | by Year (desc) | by Author (A-Z) | by Author (Z-A)Leoni, L., Mellini, M., Merlino, S., Orlandi, P. (1979) Cancrinite-like minerals: new data and crystal chemical considerations. Rendiconti della Società Italiana di Mineralogia e Petrologia: 35: 713-719.Hassan, I., Grundy, H.D. (1984) The crystal structures of sodalite-group minerals. Acta Crystallographica: B40: 6-13.Ivanov, V.G., Sapozhnikov, A.N., Piskunova, L.F., Kashayev, A.A. (1992) Tounkite (Na,Ca,K)8(Al6Si6O24)(SO4)2Cl·H2O- a new cancrinite-like mineral. Zapiski Vserossijskogo Mineralogicheskogo Obshchestva: 121(2): 92-95.Jambor, J.L., Grew, E.S. (1994) New mineral names. American Mineralogist: 79: 185-189 (187).Ballirano, P., Maras, A., Buseck, P.R. (1996) Crystal chemistry and IR spectroscopy of Cl- and SO4-bearing cancrinite-like minerals. American Mineralogist: 81: 1003-1012.New Minerals (1997) New Minerals 1990-1994.Rozenberg, K.A., Sapozhnikov, A.N., Rastsvetaeva, R.K., Bolotina, N.B., Kashaev, A.A. (2004) Crystal structure of a new representative of the cancrinite group with a 12-layer stacking sequence of tetrahedral rings. Crystallography Reports: 49: 635-642.Krivovichev, S.V. (2013) Structural complexity of minerals: information storage and processing in the mineral world. Mineralogical Magazine: 77: 275-326.\n',
#   'mindat.org URL': 'https://www.mindat.org/min-4002.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Tounkite on Google\nLook for Tounkite images on Google',
#   'External Links': 'Look for Tounkite on Webmineral\nLook for Tounkite on Wikipedia\nLook for Tounkite on Mineralien Atlas\nRaman and XRD data at RRUFF project\nReferences and PDF downloads at RRUFF project\nAmerican Mineralogist Crystal Structure Database\nHandbook of Mineralogy page PDF',
#   'Mineral Dealers': 'Quality Minerals at Fair PricesBuy from McDougall MineralsBlue Gems Australian & InternationalHigh-end worldwide specimens & outstanding customer serviceWendel Minerals - Auction & ShopTop quality minerals from Kristalle of CaliforniaBuy from David K Joyce mineralsBuy rare minerals from Excalibur MineralsWilensky Exquisite MineralsFine Minerals from Weinrich Minerals, Inc.Quality Mineral Specimens For Sale ~ Cal Neva Mineral Company'},
#  'Tourmaline': {'Formula': ['A(D3)G6(Si6O18)(BO3)3X3ZA = Ca, Na, K, Pb or is vacant (large cations);\n\nD = Al, Fe2+, Fe3+, Li, Mg2+, Mn2+, Ti (intermediate to small cations - in valence balancing combinations when the A site is vacant);\n\nG = Al, Cr3+, Fe3+, V3+ (small cations);\n\nSi can sometimes have minor Al and/or B3+ substitution.\n\nX = O and/or OH;\n\nZ = F, O and/or OH.\n\nNote: In the formulas of the group members, we have put the D site cations in parentheses in order to facilitate the assignment of the different cations to the crystallographic sites.\n',
#    'A(D3)G6(Si6O18)(BO3)3X3Z'],
#   'Hardness': ['7 on Mohs scale', '7'],
#   'Specific Gravity': '2.9 - 3.1',
#   'Crystal System': 'Trigonal',
#   'Name': 'Reported by Christianus-Fridericus Garmann in 1707. The name "tourmali" was a generic name used in Ceylon [Sri Lanka] for colored gems, mostly zircons. About 1703, it had been discovered by Dutch lapidaries that some of the "zircons" arriving in the Netherlands were actually a previously undescribed mineral. Several names were given to the new mineral including "Pierre de Ceylan, by Lemery in 1717. Tourmalin, as a more or less specific mineral name, was used by Rinmann in 1766. Hill called it Tourmaline Garnet in 1771 and Richard Kirwan shortened the name to "Tourmaline" in 1794.',
#   'Pronounciation': "PlayRecorded byCountry\n\n\nSorry, your browser doesn't support HTML5 audio.Jolyon & Katya RalphUnited Kingdom",
#   'Fracture': 'Irregular/Uneven, Conchoidal',
#   'Density': '2.9 - 3.1 g/cm3 (Measured) \xa0\xa0\xa0',
#   'Crystal Atlas': '\n\nImage Loading\n\n\n\n\n\n\n\n\nClick on an icon to view\n\n\n\n\nTourmaline no.4 - Goldschmidt (1913-1926)\n\n\n\n\n\nTourmaline no.309 - Goldschmidt (1913-1926)\n\n\n\n\n\n3d models and HTML5 code kindly provided by\nwww.smorf.nl.\nToggle\nEdge Lines |\nMiller Indices |\nAxes\n\nTransparency\nOpaque |\nTranslucent |\nTransparent\n\nView\nAlong a-axis |\nAlong b-axis |\nAlong c-axis |\nStart rotation |\nStop rotation\n\n\n',
#   'Health Risks': 'No information on health risks for this material has been entered into the database. You should always treat mineral specimens with care.',
#   'Reference List
G., Frank-Kamenetskaya, O.V., and Frank-Kamenetskii, V.A. (year?) Some problems of structural crystallochemistry of tourmalines. Crystal chemistry of minerals. Papers and Proceedings of the General Meeting International Mineralogical Association: 33: 532-540.Dietrich, R. V. (1985) The tourmaline group. 1st ed., Van Nostrand Reinhold, New York, 300 pp.Henry, D.J. and Guidotti, C.V. (1985) Tourmaline as a petrogenic indicator mineral: an example from the staurolite-grade metapelites of NW Maine. American Mineralogist: 70: 1-15.Dietrich, R. V. (1986) The tourmaline group. Kluwer, xx pp.Sesedko, T.A. and Mischenko, K.S. (1986) K voprosu rentgenovskoy diagnostiki turmalinov (X-ray diagnosis of tourmaline). Zapiski Vserossiyskogo Mineralogicheskogo Obshchestva: 115(3): 369-377 (in Russian).Mattson, S.M. and Rossma ...
#   'mindat.org URL': 'https://www.mindat.org/min-4003.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Tourmaline on Google\nLook for Tourmaline images on Google',
#   'Mineral Dealers': 'Buy from David K Joyce mineralsHigh-end worldwide specimens & outstanding customer serviceWendel Minerals - Auction & ShopQuality Minerals at Fair PricesFine Minerals from Weinrich Minerals, Inc.Top quality minerals from Kristalle of CaliforniaWilensky Exquisite MineralsFabre Minerals - search for Tourmaline specimensBlue Gems Australian & InternationalQuality Mineral Specimens For Sale ~ Cal Neva Mineral CompanyBuy from McDougall Minerals'},
#  'Toyohaite': {'Formula': 'Ag1+(Fe2+0.5Sn4+1.5)S4',
#   'Colour': 'Gray-brown',
#   'Lustre': 'Metallic',
#   'Hardness': ['4', '4 on Mohs scale'],
#   'Crystal System': 'Tetragonal',
#   'Member of': 'Carrollite Subgroup > Thiospinel Group > Spinel Supergroup',
#   'Name': 'Named after its discovery locality, Toyoha Mine, Sapporo, Hokkaido, Japan.',
#   'Type Locality': 'ⓘ Toyoha mine, Minami-ku, Sapporo City, Ishikari Subprefecture, Hokkaidō Prefecture, Japan',
#   'Isostructural with': 'Rhodostannite',
#   'IMA status': 'Approved',
#   'IMA status notes': 'Redefined by the IMA',
#   'Approval year': '1989',
#   'First published': '1991',
#   'Approval history': 'Redefined by IMA as Ag1+(Fe2+0.5Sn4+1.5)S4 Bosi et al. 2018)',
#   'Strunz 8th ed.': '2/C.06-160',
#   'Nickel-Strunz 10th (pending) ed.': '2.DA.102 : SULFIDES and SULFOSALTS (sulfides, selenides, tellurides; arsenides, antimonides, bismuthides; sulfarsenites, sulfantimonites, sulfbismuthites, etc.)D : Metal Sulfides, M: S = 3 :4 and 2:3A : M:S = 3:4',
#   'Dana 8th ed.': '2.10.3.22 : SULFIDES10 : AmBnXp, with (m+n):p = 3:4',
#   'Transparency': 'Opaque',
#   'Anisotropism': 'Distinct to strong, greenish gray to reddish brown',
#   'Bireflectance': 'Very weak',
#   'Reflectivity': ' 480nmR1=23.5%R2= 24.3% 546nmR1=24.1%R2= 26.1% 589nmR1=24.7%R2= 26.4% 650nmR1=26.5%R2= 28.3%Graph shows reflectance levels at different wavelengths (in nm). Top of box is 100%. Peak reflectance is 28.3%.R1 shown in black, R2 shown in red',
#   'Colour in reflected light': 'Brownish grey',
#   'Internal Reflections': 'None',
#   'Elements listed': 'Ag, Fe, S, Sn - search for minerals with similar chemistry',
#   'Common Impurities': 'Cu,Zn,Cd',
#   'Twinning': 'Twinning is recognized under high magnification',
#   'Reference': 'Yajima, J., Ohta, E., Kanazawa, Y. (1991) Toyohaite, Ag2FeSn3S8, a new mineral. Mineralogical Journal: 15: 222-232.',
#   'Download': 'https://rruff.info/rruff_1.0/uploads/MJ15_222.pdf',
#   'Health Risks': 'No information on health risks for this material has been entered into the database. You should always treat mineral specimens with care.',
#   'Reference List': 'Sort by Year (asc) | by Year (desc) | by Author (A-Z) | by Author (Z-A)Yajima, J., Ohta, E., Kanazawa, Y. (1991) Toyohaite, Ag2FeSn3S8, a new mineral. Mineralogical Journal: 15: 222-232.Jambor, J.L., Puziewicz, J. (1992) New mineral names. American Mineralogist: 77: 1116-1121.New Minerals (1997) New Minerals 1990-1994.Bosi, F., Biagioni, C., Pasero, M. (2019) Nomenclature and classification of the spinel supergroup. European Journal of Mineralogy: 31: 183-192.\n',
#   'mindat.org URL': 'https://www.mindat.org/min-4004.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Toyohaite on Google\nLook for Toyohaite images on Google',
#   'External Links': 'Look for Toyohaite on Webmineral\nLook for Toyohaite on Wikipedia\nLook for Toyohaite on Mineralien Atlas\nRaman and XRD data at RRUFF project\nReferences and PDF downloads at RRUFF project\nAmerican Mineralogist Crystal Structure Database\nHandbook of Mineralogy page PDF',
#   'Mineral Dealers': 'Blue Gems Australian & InternationalTop quality minerals from Kristalle of CaliforniaHigh-end worldwide specimens & outstanding customer serviceWilensky Exquisite MineralsBuy from McDougall MineralsQuality Mineral Specimens For Sale ~ Cal Neva Mineral CompanyBuy from David K Joyce mineralsWendel Minerals - Auction & ShopBuy rare minerals from Excalibur MineralsFabre Minerals - search for Toyohaite specimensQuality Minerals at Fair PricesFine Minerals from Weinrich Minerals, Inc.'},
#  'Trabzonite': {'IMA status': 'Approved',
#   'Approval year': '1983',
#   'First published': '1986',
#   'Strunz 8th ed.': '8/C.28-20',
#   'Nickel-Strunz 10th (pending) ed.': '9.BJ.159 : SILICATES (Germanates)B : SorosilicatesJ : Sorosilicates with Si3O10, Si4O11, etc. anions; cations in octahedral [6] and greater coordination',
#   'Dana 8th ed.': '57.1.3.157 : SOROSILICATES Si3O10 Groups and Larger Noncyclic Groups1 : Insular Si3O10 and Larger Noncyclic Groups with [Si3O10] groups',
#   "Hey's CIM Ref.": '14.5.2014 : Silicates not Containing Aluminum5 : Silicates of Ca',
#   'Lustre': 'Vitreous',
#   'Transparency': 'Transparent',
#   'Colour': 'Colourless',
#   'Streak': 'White',
#   'Cleavage': 'None Observed',
#   'Fracture': 'Conchoidal',
#   'Density': '2.9 g/cm3 (Measured) \xa0\xa0\xa0',
#   'Comment': ['Originally assumed to be P21/m.', 'Measured by suspension'],
#   'Type': 'Biaxial (+)',
#   'RI values': ' nα = 1.632 nβ = 1.634 nγ = 1.640',
#   '2V': 'Measured: 55° to 60°, Calculated: 62° ',
#   'Surface Relief': 'Moderate',
#   'Dispersion': 'weak to distinct',
#   'Formula': 'Ca4(Si3O9)(OH)2',
#   'IMA Formula': 'Ca4[Si3O9(OH)](OH)',
#   'Elements listed': 'Ca, H, O, Si - search for minerals with similar chemistry',
#   'Common Impurities': 'Al,Mn,Mg,Na',
#   'Crystal System': 'Orthorhombic',
#   'Class (H-M)': 'mm2 - Pyramidal',
#   'Space Group': 'Ama2',
#   'Cell Parameters': 'a = 20.6 Å, b = 9.1 Å, c = 10.3 Åβ = 98°',
#   'Type Locality': 'ⓘ Esquire No. 1 claim, Rush Creek, Big Creek-Rush Creek Mining District, Fresno Co., California, USA',
#   'IMA status': 'Approved',
#   'Approval year': '1964',
#   'First published': '1965',
#   'Strunz 8th ed.': '8/E.20-20',
#   'Nickel-Strunz 10th (pending) ed.': '9.CP.059 : SILICATES (Germanates)C : CyclosilicatesP : 12-membered and larger rings',
#   'Dana 8th ed.': '64.5.1.164 : CYCLOSILICATES Rings with Other Anions and Insular Silicate Groups5 : Rings with Other Anions and Insular Silicate Groups: 12-membered rings with [Si2O7] dimers',
#   "Hey's CIM Ref.": '17.3.1717 : Silicates Containing other Anions3 : Silicates with chloride (including aluminosilicates)',
#   'Streak': 'light red-brown',
#   'Cleavage': 'None Observed',
#   'Fracture': 'Conchoidal',
#   'Density': '3.71(2) g/cm3 (Measured) \xa0\xa0\xa0',
#   'Type': 'Uniaxial (-)',
#   'RI values': ' nω = 1.714 nε = 1.702',
#   'Surface Relief': 'High',
#   'Comments': 'Brownish-red to colorless.',
#   'IMA Formula': 'Ba21Ca(Fe2+,Mn,Ti)4(Ti,Fe,Mg)12(Si12O36)(Si2O7)6(O,OH)30Cl6 · 14H2O',
#   'Elements listed': 'Ba, Ca, Cl, Fe, H, Mg, Mn, O, Si, Ti - search for minerals with similar chemistry',
#   'Common Impurities': 'Al,Mn,Mg,Ca,Sr,K',
#   'Cell Parameters': 'a = 17.89 Å, c = 12.33 Å',
#   'Ratio': 'a:c = 1 : 0.689',
#   'Unit Cell V': '3,417.55 Å³ (Calculated from Unit Cell)',
#   'Morphology': 'Generally anhedral grains. Euhedral crystals show the forms {0001} and {10-10} prominently, but many tiny pyramid faces occur on some crystals. Tentative forms include {ll-22}, (41-52), and (61-71).',
#   'Reference': 'Alfors, J.T., Stinson, M.C., Matthews, R.A., and Pabst, A. (1965) Seven new barium minerals from eastern Fresno County, California. American Mineralogist: 50: 314-340.',
#   'Download': 'http://rruff.info/rruff_1.0/uploads/AM50_314.pdf',
#   'In UV light': 'None observed',
#   'Thermal Behaviour': 'Gives off water in a closed tube test.\n\nRapidly heated to 900 C in an electric furnace, the mineral turns light brown. At 1200 C the mineral melts completely to a straw yellow glass.',
#   'Notes': 'Insoluble in dilute acids and bases. On prolonged standing in dilute hydrochloric acid, the mineral turns almost opaque brown and loses its glassy appearance.',
#   'Health Risks': 'No information on health risks for this material has been entered into the database. You should always treat mineral specimens with care.',
#   'Reference List': 'Sort by Year (asc) | by Year (desc) | by Author (A-Z) | by Author (Z-A)Alfors, J.T., Stinson, M.C., Matthews, R.A., and Pabst, A. (1965) Seven new barium minerals from eastern Fresno County, California. American Mineralogist: 50: 314-340.Alfors, J.T. and Putnam, G.W. (1965) Revised chemical analyses of traskite, verplanckite and muirite from Fresno County, California: American Mineralogist: 50: 1500-1503.Malinovskii, Y.A., Pobedimskaya, E.A., Belov, N.V. (1976) Crystal structure of traskite. Doklady Akademii Nauk SSSR: 229: 1101-1104.Malinovskii, Y.A., Pobedimskaya, E.A., Belov, N.V. (1976) Crystal structure of traskite. Soviet Physics - Doklady: 21: 426-428.\n',
#   'mindat.org URL': 'https://www.mindat.org/min-4007.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Traskite on Google\nLook for Traskite images on Google',
#   'External Links': 'Look for Traskite on Webmineral\nLook for Traskite on Wikipedia\nLook for Traskite on Mineralien Atlas\nRaman and XRD data at RRUFF project\nReferences and PDF downloads at RRUFF project\nAmerican Mineralogist Crystal Structure Database\nHandbook of Mineralogy page PDF',
#   'Mineral Dealers': 'Wendel Minerals - Auction & ShopWilensky Exquisite MineralsBlue Gems Australian & InternationalBuy rare minerals from Excalibur MineralsQuality Mineral Specimens For Sale ~ Cal Neva Mineral CompanyBuy from David K Joyce mineralsQuality Minerals at Fair PricesBuy from McDougall MineralsFine Minerals from Weinrich Minerals, Inc.High-end worldwide specimens & outstanding customer serviceFabre Minerals - search for Traskite specimens'},
#  'Treasurite': {'Formula': 'Ag7Pb6Bi15S32',
#   'Colour': 'Black',
#   'Lustre': 'Metallic',
#   'Crystal System': 'Monoclinic',
#   'Member of': 'Lillianite Homologous Series Group',
#   'Name': 'Named after its discovery locality, the Treasure Vault Mine, Colorado, USA.',
#   'Type Locality': 'ⓘ Treasury Vault Mine, Geneva Mining District, Park County, Colorado, USA',
#   'IMA status': 'Approved',
#   'Approval year': '1976',
#   'Strunz 8th ed.': '2/E.31-80',
#   'Nickel-Strunz 10th (pending) ed.': '2.JB.40a2 : SULFIDES and SULFOSALTS (sulfides, selenides, tellurides; arsenides, antimonides, bismuthides; sulfarsenites, sulfantimonites, sulfbismuthites, etc.)J : Sulfosalts of PbS archetypeB : Galena derivatives, with Pb',
#   'Dana 8th ed.': '3.6..33 : SULFOSALTS6 : 2 < ø < 2.49',
#   "Hey's CIM Ref.": '5.7.385 : Sulphosalts - Sulpharsenites and Sulphobismuthites (those containing Sn, Ge,or V are in Section 6)7 : Sulpharsenites etc. of Pb and other metals',
#   'Pronounciation': "PlayRecorded byCountry\n\n\nSorry, your browser doesn't support HTML5 audio.Jolyon & Katya RalphUnited Kingdom",
#   'Transparency': 'Opaque',
#   'IMA Formula': 'Ag7Pb6Bi15S30',
#   'Elements listed': 'Ag, Bi, Pb, S - search for minerals with similar chemistry',
#   'Cell Parameters': 'a = 26.53 Å, b = 4.09 Å, c = 13.34 Åβ = 92.77°',
#   'Ratio': 'a:b:c = 6.487 : 1 : 3.262',
#   'Unit Cell V': '1,445.80 Å³ (Calculated from Unit Cell)',
#   'Health Risks': 'No information on health risks for this material has been entered into the database. You should always treat mineral specimens with care.',
#   'Reference List': 'Sort by Year (asc) | by Year (desc) | by Author (A-Z) | by Author (Z-A)Makovicky, E. and Karup-Møller, S. (1977b) Chemistry and crystallography of the lillianite homologous series. II. Definition of new minerals eskimoite, vikingite, ourayite and treasurite. Redefinition of schirmerite and new data on the lillianite-gustavite solid-solution series. Neues Jahrbuch für Mineralogie, Abhandlungen: 131: 56-82.Bulletin of the Geological Society of Denmark (1977): 26: 41-68.American Mineralogist (1979): 64: 243.Neues Jahrbuch für Mineralogie, Abhandlungen: 131: 56-82.\n',
#   'mindat.org URL': 'https://www.mindat.org/min-4008.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Treasurite on Google\nLook for Treasurite images on Google',
#   'External Links': 'Look for Treasurite on Webmineral\nLook for Treasurite on Wikipedia\nLook for Treasurite on Mineralien Atlas\nRaman and XRD data at RRUFF project\nReferences and PDF downloads at RRUFF project\nAmerican Mineralogist Crystal Structure Database\nHandbook of Mineralogy page PDF',
#   'Mineral Dealers': 'Fabre Minerals - search for Treasurite specimensWilensky Exquisite MineralsFine Minerals from Weinrich Minerals, Inc.Top quality minerals from Kristalle of CaliforniaQuality Minerals at Fair PricesHigh-end worldwide specimens & outstanding customer serviceQuality Mineral Specimens For Sale ~ Cal Neva Mineral CompanyBlue Gems Australian & InternationalBuy from McDougall MineralsBuy rare minerals from Excalibur MineralsBuy from David K Joyce minerals'},
#  'Trechmannite': {'Formula': 'AgAsS2',
#   'Colour': 'Deep vermilion-red',
#   'Lustre': 'Adamantine',
#   'Hardness': ['1½ - 2 on Mohs scale',
#    '1½ - 2',
#    'VHN25=97 - 100 kg/mm2 - Vickers'],
#   'Specific Gravity': '4.77 (Calculated)',
#   'Crystal System': 'Trigonal',
#   'Name': 'Named after Charles Otto Trechmann (19 March 1851, Hartlepool, England - 29 June 1917), English cement mill owner and spare-time crystallographer.',
#   'Type Locality': 'ⓘ Lengenbach Quarry, Fäld, Binn, Goms, Valais, Switzerland',
#   'Dimorph of': 'Smithite',
#   'IMA status': "Approved, 'Grandfathered' (first described prior to 1959)",
#   'First published': '1905',
#   'Strunz 8th ed.': '2/E.08-10',
#   'Nickel-Strunz 10th (pending) ed.': '2.GC.352 : SULFIDES and SULFOSALTS (sulfides, selenides, tellurides; arsenides, antimonides, bismuthides; sulfarsenites, sulfantimonites, sulfbismuthites, etc.)G : Sulfarsenites, sulfantimonites, sulfbismuthitesC : Poly-sulfarsenites',
#   'Dana 8th ed.': '3.7.2.13 : SULFOSALTS7 : ø = 2',
#   "Hey's CIM Ref.": '5.2.25 : Sulphosalts - Sulpharsenites and Sulphobismuthites (those containing Sn, Ge,or V are in Section 6)2 : Sulpharsenites etc. of Ag',
#   'Transparency': 'Transparent, Translucent',
#   'Streak': 'scarlet red',
#   'Tenacity': 'Brittle',
#   'Cleavage': 'Distinct/GoodGood on {1011}, distinct on {0001}',
#   'Fracture': 'Conchoidal',
#   'Density': '4.77 g/cm3 (Calculated)',
#   'Comment': 'Calculated on synthetic material',
#   'Type': 'Uniaxial (-)',
#   'RI values': ' nω = 2.600 nε = 2.400',
#   'Surface Relief': 'Very High',
#   'Bireflectance': 'Extreme',
#   'Reflectivity': ' 400nmR1=26.2%R2=37.6% 420nmR1=25.7%R2=36.9% 440nmR1=24.9%R2=35.5% 460nmR1=23.7%R2=33.8% 480nmR1=23.0%R2=32.6% 500nmR1=23.4%R2=31.6% 520nmR1=23.7%R2=30.7% 540nmR1=23.4%R2=29.9% 650nmR1=22.7%R2=29.1% 580nmR1=22.1%R2=28.5% 600nmR1=21.5%R2=28.0% 620nmR1=21.0%R2=27.6% 640nmR1=20.6%R2=27.2% 660nmR1=20.3%R2=26.9% 680nmR1=20.0%R2=26.4% 700nmR1=19.9%R2=26.2%Graph shows reflectance levels at different wavelengths (in nm). Top of box is 100%. Peak reflectance is 37.6%.R1 shown in black, R2 shown in red',
#   'Colour in reflected light': ' Scarlet-vermilion with bluish cast',
#   'Internal Reflections': 'red-orange ',
#   'Pleochroism': 'Weak',
#   'Comments': 'Faint with O = pale reddish, E = clear and nearly colorless',
#   'Elements listed': 'Ag, As, S - search for minerals with similar chemistry',
#   'Class (H-M)': '3 - Rhombohedral',
#   'Space Group': 'R3',
#   'Cell Parameters': 'a = 13.98 Å, c = 9.12 Å',
#   'Ratio': 'a:c = 1 : 0.652',
#   'Unit Cell V': '1,543.62 Å³ (Calculated from Unit Cell)',
#   'Z': '18',
#   'Morphology': 'Short prismatic, equant. Sometimes irregular.',
#   'IMA status': 'Approved',
#   'Approval year': '1991',
#   'Strunz 8th ed.': '5/L.04-35',
#   'Nickel-Strunz 10th (pending) ed.': '6.GA.106 : BORATESG : Heptaborates and other megaboratesA : Tekto-heptaborates',
#   'Dana 8th ed.': '25.6.2.225 : ANHYDROUS BORATES CONTAINING HYDROXYL OR HALOGEN6 : Hexaborates',
#   'Transparency': 'Transparent',
#   'Type': 'Uniaxial (-)',
#   'RI values': ' nω = 1.684 nε = 1.668',
#   'Surface Relief': 'High',
#   'IMA Formula': 'Mg3B7O13Cl',
#   'Elements listed': 'B, Cl, Fe, Mg, O - search for minerals with similar chemistry',
#   'Common Impurities': 'Mn,Ca',
#   'Cell Parameters': 'a = 8.57 Å, c = 20.99 Å',
#   'Ratio': 'a:c = 1 : 2.449',
#   'Unit Cell V': '1,335.07 Å³ (Calculated from Unit Cell)',
#   'Health Risks': 'No information on health risks for this material has been entered into the database. You should always treat mineral specimens with care.',
# ...
#   'mindat.org URL': 'https://www.mindat.org/min-4644.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Ktypéite on Google\nLook for Ktypéite images on Google'},
#  'Gel-Cassiterite': {'mindat.org URL': 'https://www.mindat.org/min-4645.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Gel-Cassiterite on Google\nLook for Gel-Cassiterite images on Google'},
#  'Arcanit': {'mindat.org URL': 'https://www.mindat.org/min-4646.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Arcanit on Google\nLook for Arcanit images on Google'},
#  'Arfvedsonite (of Brooke)': {'mindat.org URL': 'https://www.mindat.org/min-4647.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Arfvedsonite (of Brooke) on Google\nLook for Arfvedsonite (of Brooke) images on Google'},
#  'α-Argentite': {'mindat.org URL': 'https://www.mindat.org/min-4648.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for α-Argentite on Google\nLook for α-Argentite images on Google'},
#  'Aarite': {'mindat.org URL': 'https://www.mindat.org/min-4650.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Aarite on Google\nLook for Aarite images on Google'},
#  'Native Arsenic': {'mindat.org URL': 'https://www.mindat.org/min-4651.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Native Arsenic on Google\nLook for Native Arsenic images on Google'},
#  'Mispickel': {'mindat.org URL': 'https://www.mindat.org/min-4652.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Mispickel on Google\nLook for Mispickel images on Google'},
#  'Arsenical Pyrites': {'mindat.org URL': 'https://www.mindat.org/min-4653.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Arsenical Pyrites on Google\nLook for Arsenical Pyrites images on Google'},
#  'Mistpuckel': {'mindat.org URL': 'https://www.mindat.org/min-4654.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Mistpuckel on Google\nLook for Mistpuckel images on Google'},
#  'Dalarnite': {'mindat.org URL': 'https://www.mindat.org/min-4655.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Dalarnite on Google\nLook for Dalarnite images on Google'},
#  'Plinian': {'mindat.org URL': 'https://www.mindat.org/min-4656.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Plinian on Google\nLook for Plinian images on Google'},
#  'Thalheimite': {'mindat.org URL': 'https://www.mindat.org/min-4657.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Thalheimite on Google\nLook for Thalheimite images on Google'},
#  'Arsenomarcasite': {'mindat.org URL': 'https://www.mindat.org/min-4658.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Arsenomarcasite on Google\nLook for Arsenomarcasite images on Google'},
#  'Arsenopolybasite (of Frondel)': {'mindat.org URL': 'https://www.mindat.org/min-4659.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Arsenopolybasite (of Frondel) on Google\nLook for Arsenopolybasite (of Frondel) images on Google'},
#  'Francolite': {'Reference List': 'Sort by Year (asc) | by Year (desc) | by Author (A-Z) | by Author (Z-A)Brooke and Henry (1850) London, Edinburgh and Dublin Philosophical Magazine and Journal of Science, London: 36: 134.Sandell, Hey, and McConnell (1939) Mineralogical Magazine: 25: 395.Palache, C., Berman, H., & Frondel, C. (1951), The System of Mineralogy of James Dwight Dana and Edward Salisbury Dana, Yale University 1837-1892, Volume II. John Wiley and Sons, Inc., New York, 7th edition, revised and enlarged, 1124 pp.: 879.\n',
#   'mindat.org URL': 'https://www.mindat.org/min-4910.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Francolite on Google\nLook for Francolite images on Google'},
#  'Dahllite': {'Reference List': 'Sort by Year (asc) | by Year (desc) | by Author (A-Z) | by Author (Z-A)Brögger, W. C and Bäckström, H. (1888): Über den "Dahllit", ein neues mineral von Ödegården, Bamle, Norwegen. Öfversigt af Kongliga Vetenskaps-Akademiens Förhandlingar (Stockholm) 1888 (7),1-4.Palache, C., Berman, H., & Frondel, C. (1951), The System of Mineralogy of James Dwight Dana and Edward Salisbury Dana, Yale University 1837-1892, Volume II. John Wiley and Sons, Inc., New York, 7th edition, revised and enlarged, 1124 pp.: 879.\n',
#   'mindat.org URL': 'https://www.mindat.org/min-4911.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Dahllite on Google\nLook for Dahllite images on Google'},
#  'Carnotite (of Friedel and Cumenge)': {'mindat.org URL': 'https://www.mindat.org/min-4912.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Carnotite (of Friedel and Cumenge) on Google\nLook for Carnotite (of Friedel and Cumenge) images on Google'},
#  'Seladonite': {'mindat.org URL': 'https://www.mindat.org/min-4913.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Seladonite on Google\nLook for Seladonite images on Google'},
#  'Verona Earth': {'mindat.org URL': 'https://www.mindat.org/min-4914.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Verona Earth on Google\nLook for Verona Earth images on Google'},
#  'Veronite': {'mindat.org URL': 'https://www.mindat.org/min-4915.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Veronite on Google\nLook for Veronite images on Google'},
#  'Cerianite': {'mindat.org URL': 'https://www.mindat.org/min-4916.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Cerianite on Google\nLook for Cerianite images on Google'},
#  'Ceriopyrochlore-(Ce) (of Hogarth 1977)': {'mindat.org URL': 'https://www.mindat.org/min-4917.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Ceriopyrochlore-(Ce) (of Hogarth 1977) on Google\nLook for Ceriopyrochlore-(Ce) (of Hogarth 1977) images on Google'},
#  'Cerite': {'Synonym of': 'Cerite-(Ce), Ferricerite-(La)',
#   'Health Risks': 'No information on health risks for this material has been entered into the database. You should always treat mineral specimens with care.',
#   'mindat.org URL': 'https://www.mindat.org/min-4918.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Cerite on Google\nLook for Cerite images on Google',
#   'Mineral Dealers': 'Fine Minerals from Weinrich Minerals, Inc.Wilensky Exquisite MineralsFabre Minerals - search for Cerite specimensQuality Minerals at Fair PricesQuality Mineral Specimens For Sale ~ Cal Neva Mineral CompanyBuy from McDougall MineralsBlue Gems Australian & InternationalBuy rare minerals from Excalibur MineralsBuy from David K Joyce mineralsHigh-end worldwide specimens & outstanding customer serviceWendel Minerals - Auction & ShopTop quality minerals from Kristalle of California'},
#  'Cerotungstite': {'Reference List': 'Sort by Year (asc) | by Year (desc) | by Author (A-Z) | by Author (Z-A)RENAMED: Ref.: American Mineralogist 72 (1987), 1031 (Appendix 2).\n',
#   'mindat.org URL': 'https://www.mindat.org/min-4919.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Cerotungstite on Google\nLook for Cerotungstite images on Google'},
#  'Acrusite': {'mindat.org URL': 'https://www.mindat.org/min-4920.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Acrusite on Google\nLook for Acrusite images on Google'},
#  'Cerussa': {'Reference List': 'Sort by Year (asc) | by Year (desc) | by Author (A-Z) | by Author (Z-A)Pliny, Ovid, Agricola, etc.Palache, C., Berman, H., & Frondel, C. (1951), The System of Mineralogy of James Dwight Dana and Edward Salisbury Dana, Yale University 1837-1892, Volume II: Halides, Nitrates, Borates, Carbonates, Sulfates, Phosphates, Arsenates, Tungstates, Molybdates, Etc. John Wiley and Sons, Inc., New York, 7th edition, revised and enlarged: 200.\n',
#   'mindat.org URL': 'https://www.mindat.org/min-4921.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Cerussa on Google\nLook for Cerussa images on Google'},
#  'Cerusite': {'mindat.org URL': 'https://www.mindat.org/min-4922.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Cerusite on Google\nLook for Cerusite images on Google'},
#  'Cerussita': {'mindat.org URL': 'https://www.mindat.org/min-4923.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Cerussita on Google\nLook for Cerussita images on Google'},
#  'Lead Spar': {'mindat.org URL': 'https://www.mindat.org/min-4924.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for
htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Chalcedonite on Google\nLook for Chalcedonite images on Google'},
#  'Chalcocine': {'mindat.org URL': 'https://www.mindat.org/min-4937.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Chalcocine on Google\nLook for Chalcocine images on Google'},
#  'Chalcosine': {'mindat.org URL': 'https://www.mindat.org/min-4938.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Chalcosine on Google\nLook for Chalcosine images on Google'},
#  'Chalcosite': {'mindat.org URL': 'https://www.mindat.org/min-4939.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Chalcosite on Google\nLook for Chalcosite images on Google'},
#  'Chalkosin': {'mindat.org URL': 'https://www.mindat.org/min-4940.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Chalkosin on Google\nLook for Chalkosin images on Google'},
#  'Calcosina': {'mindat.org URL': 'https://www.mindat.org/min-4941.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Calcosina on Google\nLook for Calcosina images on Google'},
#  'Vitreous Copper': {'mindat.org URL': 'https://www.mindat.org/min-4942.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Vitreous Copper on Google\nLook for Vitreous Copper images on Google'},
#  'Copper Glance': {'mindat.org URL': 'https://www.mindat.org/min-4943.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Copper Glance on Google\nLook for Copper Glance images on Google'},
#  'Cuivre Sulfuré Spiciforme': {'mindat.org URL': 'https://www.mindat.org/min-4944.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Cuivre Sulfuré Spiciforme on Google\nLook for Cuivre Sulfuré Spiciforme images on Google'},
#  'Cyprite': {'mindat.org URL': 'https://www.mindat.org/min-4945.htmlPlease feel free to link to this page.',
#   'Search Engines': 'Look for Cyprite on Google\nLook for Cyprite images on Google'},
#  ...}

# %%
len(data.keys())
# Out:
# 9112

# %%
All_Attribute= []
Mineral_List = []
for mineral in data.keys():
    Mineral_List.append(mineral)
    for att in data[mineral].keys():
        All_Attribute.append(att)
        
All_Attribute = list(set(All_Attribute))

# %%
print(len(All_Attribute))
All_Attribute
# Out:
# 101
# ['Interestingness',
#  'Special Storage/Display Requirements',
#  'Type Locality',
#  'CAS Registry number',
#  'Comments',
#  'Bireflectance',
#  "Hey's CIM Ref.",
#  'German name for',
#  'Hardness',
#  'Colour in reflected light',
#  'Co-Type Localities',
#  'Common Impurities',
#  'Idealised Formula',
#  'Tenacity',
#  'Translation gliding',
#  'Recorded ages',
#  'Pronounciation',
#  'Magnetism',
#  'Specific Gravity',
#  'First Recorded Locality',
#  'Class (H-M)',
#  'Nickel-Strunz 10th (pending) ed.',
#  'IMA status notes',
#  'Mineral Dealers',
#  'Internal Reflections',
#  'IMA Formula',
#  'Elements listed',
#  'Reflectivity',
#  'Polymorph of',
#  'Approval history',
#  'Epitaxial Minerals',
#  'Synonym of',
#  'Health Risks',
#  'Download',
#  'IR Spectrum',
#  'Series Formula',
#  'Ratio',
#  'Geological Setting',
#  'Comment',
#  'Electrical',
#  'Setting',
#  'In UV light',
#  'Search Engines',
#  'External Links',
#  'Transparency',
#  'Type',
#  'Epitaxy Comments',
#  'Density',
#  'Industrial Uses',
#  'Dispersion',
#  'Dimorph of',
#  'Name',
#  'Notes',
#  '2V',
#  'Powder Diffraction Data',
#  'Reference',
#  'Cleavage',
#  'RI values',
#  'Crystal Atlas',
#  'Anisotropism',
#  'German synonym of',
#  'Strunz 9th ed.',
#  'Thermal Behaviour',
#  'A Mixture Of',
#  'Space Group',
#  'Z',
#  'Birefringence',
#  'Colour',
#  'Optical Extinction',
#  'Member of',
#  'Dana 7th ed.',
#  'French synonym of',
#  'Hardness Data',
#  'Co-First Recorded Localities',
#  'Fracture',
#  'Strunz 8th ed.',
#  'Reference List',
#  'First published',
#  'Sample references',
#  'Cell Parameters',
#  'Epitaxi Comments',
#  'Synonym',
#  'Streak',
#  'mindat.org URL',
#  'Crystal System',
#  'Approval year',
#  'Morphology',
#  'Dana 8th ed.',
#  'Surface Relief',
#  'Formula',
#  'Unit Cell V',
#  'Twinning',
#  'First Recorded Localities',
#  'As a Commodity',
#  'IMA status',
#  'Isostructural with',
#  'Pleochroism',
#  'Parting',
#  'Empirical formulas',
#  'Lustre',
#  'Oxide wt%']

# %%
AttributeData = defaultdict(list)

# %%
for mineral in Mineral_List:
    AttributeData['Mineral Name'].append(mineral)
    #FinalData['Mineral Name'] = mineral
    for att in All_Attribute:
        try:
            AttributeData[att].append(data[mineral][att])
        except:
            AttributeData[att].append(None)

# %%
FinalData = {}

for key in AttributeData.keys():
    FinalData[key] = AttributeData[key]
    #print(len(AttributeData[key]))

# %%
df = pd.DataFrame(FinalData)
df
# Out:
#       Mineral Name Interestingness Special Storage/Display Requirements  \
# 0        Torreyite            None                                 None
# 1         Tosudite            None                                 None
# 2         Tounkite            None                                 None
# 3       Tourmaline            None                                 None
# 4        Toyohaite            None                                 None
# ...            ...             ...                                  ...
# 9107   Colomeraite            None                                 None
# 9108        Pomite            None                                 None
# 9109  Pseudopomite            None                                 None
# 9110     Shimenite            None                                 None
# 9111      Dewitite            None                                 None
#
#                                           Type Locality CAS Registry number  \
# 0     ⓘ Sterling Mine, Sterling Hill, Ogdensburg, Fr...                None
# 1     ⓘ Solnechnogorsk Village (Kuru-Uzen'), Alushta...                None
# 2                                                  None                None
# 3                                                  None                None
# 4     ⓘ Toyoha mine, Minami-ku, Sapporo City, Ishika...                None
# ...                                                 ...                 ...
# 9107  ⓘ Colomera meteorite, Benalúa de las Villas, G...                None
# 9108  ⓘ Blue Streak Mine, Bull Canyon Mining Distric...                None
# 9109  ⓘ Blue Streak Mine, Bull Canyon Mining Distric...                None
# 9110  ⓘ Jiepaiyu Mine (Shimen Mine), Shimen deposit ...                None
# 9111  ⓘ Jas Roux, La Chapelle-en-Valgaudemar, Gap, H...                None
#
#                                                Comments Bireflectance  \
# 0     [Refractive index is decidedly higher than moo...          None
# 1                                                  None          None
# 2                                                  None          None
# 3                                                  None          None
# 4                                                  None     Very weak
# ...                                                 ...           ...
# 9107                                               None          None
# 9108                                               None          None
# 9109                                               None          None
# 9110                                               None          None
# 9111                                               None          None
#
#                                 Hey's CIM Ref. German name for  \
# 0     25.9.1125 : Sulphates9 : Sulphates of Mn            None
# 1                                         None            None
# 2                                         None            None
# 3                                         None            None
# 4                                         None            None
# ...                                        ...             ...
# 9107                                      None            None
# 9108                                      None            None
# 9109                                      None            None
# 9110                                      None            None
# 9111                                      None            None
#
#                             Hardness  ...  \
# 0               [3, 3 on Mohs scale]  ...
# 1       [1 - 2, 1 - 2 on Mohs scale]  ...
# 2     [5 - 5½ on Mohs scale, 5 - 5½]  ...
# 3               [7 on Mohs scale, 7]  ...
# 4               [4, 4 on Mohs scale]  ...
# ...                              ...  ...
# 9107                            None  ...
# 9108                            None  ...
# 9109                            None  ...
# 9110                            None  ...
# 9111                            None  ...
#
#                                                Twinning  \
# 0     Intricately polysynthetically twinned with twi...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4       Twinning is recognized under high magnification
# ...                                                 ...
# 9107                                               None
# 9108                                               None
# 9109                                               None
# 9110                                               None
# 9111                                               None
#
#      First Recorded Localities As a Commodity  \
# 0                         None           None
# 1                         None           None
# 2                         None           None
# 3                         None           None
# 4                         None           None
# ...                        ...            ...
# 9107                      None           None
# 9108                      None           None
# 9109                      None           None
# 9110                      None           None
# 9111                      None           None
#
#                                              IMA status Isostructural with  \
# 0     Approved, 'Grandfathered' (first described pri...     Lawsonbauerite
# 1     Approved, 'Grandfathered' (first described pri...               None
# 2                                              Approved               None
# 3                                                  None               None
# 4                                              Approved      Rhodostannite
# ...                                                 ...                ...
# 9107                      Approved, Pending publication               None
# 9108                      Approved, Pending publication               None
# 9109                      Approved, Pending publication               None
# 9110                      Approved, Pending publication               None
# 9111                      Approved, Pending publication               None
#
#          Pleochroism Parting Empirical formulas  \
# 0     Non-pleochroic    None               None
# 1               None    None               None
# 2               None    None               None
# 3               None    None               None
# 4               None    None               None
# ...              ...     ...                ...
# 9107            None    None               None
# 9108            None    None               None
# 9109            None    None               None
# 9110            None    None               None
# 9111            None    None               None
#
#                                     Lustre Oxide wt%
# 0     Vitreous, Sub-Vitreous, Pearly, Dull      None
# 1                               Waxy, Dull      None
# 2                                 Vitreous      None
# 3                                     None      None
# 4                                 Metallic      None
# ...                                    ...       ...
# 9107                                  None      None
# 9108                                  None      None
# 9109                                  None      None
# 9110                                  None      None
# 9111                                  None      None
#
# [9112 rows x 102 columns]

# %%
print(len(df.columns))
print(len(df))
# Out:
# 102
# 9112

# %%
cnt = 0 
for col in df.columns:
    
    blanks = df[col].isnull().sum()
    if blanks >8800:
        cnt +=1
        print(col,' : ',df[col].isnull().sum())
        df = df.drop([col],axis=1)
        
print(cnt)
# Out:
# Interestingness  :  9111
# Special Storage/Display Requirements  :  9035
# CAS Registry number  :  9075
# Bireflectance  :  8856
# German name for  :  9111
# Idealised Formula  :  8980
# Translation gliding  :  9099
# Recorded ages  :  9068
# Magnetism  :  9042
# First Recorded Locality  :  9009
# IMA status notes  :  8896
# Internal Reflections  :  8803
# Polymorph of  :  8988
# Epitaxial Minerals  :  9027
# Synonym of  :  9053
# IR Spectrum  :  8993
# Series Formula  :  9107
# Electrical  :  9052
# Epitaxy Comments  :  9051
# Industrial Uses  :  8958
# Dimorph of  :  8819
# Crystal Atlas  :  8832
# German synonym of  :  9111
# Strunz 9th ed.  :  8915
# Thermal Behaviour  :  8962
# A Mixture Of  :  9095
# Optical Extinction  :  8815
# French synonym of  :  9111
# Co-First Recorded Localities  :  9103
# Sample references  :  8939
# Epitaxi Comments  :  9105
# Synonym  :  9097
# First Recorded Localities  :  9104
# As a Commodity  :  9088
# Empirical formulas  :  9046
# Oxide wt%  :  8966
# 36

# %%
col_drop_lst = ['Approval year','Search Engines','Reference List','Mineral Dealers','Comment','External Links','Download','Comments','mindat.org URL','First published','Reference','Z']
#col_crpt_data_lst = ['Cleavage', 'Forms']   #Data is not correct

col_name_lst = ['Name']
col_formula_lst = ['Formula','IMA status', 'IMA Formula']
col_clr_lst = ['Colour','Streak','Lustre','Transparency','Pleochroism']
col_strctr_lst = ['Density','Hardness','Crystal System','Specific Gravity','Tenacity']
col_texture_lst = ['Surface Relief', 'Fracture','Morphology']
col_compound_lst = ['Elements listed', 'Common Impurities','Geological Setting','Member of',"Hey's CIM Ref.","Nickel-Strunz 10th (pending) ed.","Type"]

# %%
len(col_drop_lst)
df=df.drop(col_drop_lst,axis=1)
df.shape
# Out:
# (9112, 54)

# %%
df.to_csv('mindat_9k_stage.csv')

# %%
list2 = list(df.columns)
list2 = set(list2)

list1 = set(['Mineral Name', 'Name', 'Formula', 'IMA Formula', 'IMA status', 'IMA Formula',
       'Colour', 'Streak', 'Lustre', 'Transparency', 'Pleochroism', 'Density',
       'Hardness', 'Crystal System', 'Specific Gravity', 'Tenacity',
       'Surface Relief', 'Fracture', 'Morphology', 'Elements listed',
       'Common Impurities', 'Geological Setting', 'Member of',
       "Hey's CIM Ref.", 'Nickel-Strunz 10th (pending) ed.', 'Type',
       'Cell Parameters', 'Powder Diffraction Data', 'Dana 8th ed.',
       'Unit Cell V', 'Space Group', 'Dispersion', 'Strunz 8th ed.',
       'RI values', 'Cleavage', 'Ratio', 'Type Locality', 'Class (H-M)',
       'Health Risks', '2V', 'Approval history', 'Colour in reflected light', 'Anisotropism',
        'Reflectivity','Dana 7th ed.','Birefringence','Isostructural with','Co-Type Localities',
        'Twinning','Parting','Notes','Mineral Dealers'])

print (len(list1))
print (len(list2))

extra = list2 - list1
extra   #
# Out:
# 51
# 54
# {'Hardness Data', 'In UV light', 'Pronounciation', 'Setting'}

# %%
rearrange_col = ['Mineral Name']
rearrange_col.extend(col_name_lst)
rearrange_col.extend(col_formula_lst)
rearrange_col.extend(col_clr_lst)
rearrange_col.extend(col_strctr_lst)
rearrange_col.extend(col_texture_lst)
rearrange_col.extend(col_compound_lst)
print(len(rearrange_col))
rearrange_col
# Out:
# 25
# ['Mineral Name',
#  'Name',
#  'Formula',
#  'IMA status',
#  'IMA Formula',
#  'Colour',
#  'Streak',
#  'Lustre',
#  'Transparency',
#  'Pleochroism',
#  'Density',
#  'Hardness',
#  'Crystal System',
#  'Specific Gravity',
#  'Tenacity',
#  'Surface Relief',
#  'Fracture',
#  'Morphology',
#  'Elements listed',
#  'Common Impurities',
#  'Geological Setting',
#  'Member of',
#  "Hey's CIM Ref.",
#  'Nickel-Strunz 10th (pending) ed.',
#  'Type']

# %%
#df = df[ ['mean'] + [ col for col in df.columns if col != 'mean' ] ]
#df = df.reindex_axis(['Col1','Col2'] + list(df.columns.drop(['Col1','Col2'])), axis=1)

# %%
df = df[ rearrange_col + [ col for col in df.columns if col not in rearrange_col ] ]
df
# Out:
#       Mineral Name                                               Name  \
# 0        Torreyite  Named in 1949 by Joan Prewitt-Hopkins in honor...
# 1         Tosudite  Named by V.A. Frank-Kamenetskii, N.V. Logvinen...
# 2         Tounkite  Named after its discovery locality, Tounka Val...
# 3       Tourmaline  Reported by Christianus-Fridericus Garmann in ...
# 4        Toyohaite  Named after its discovery locality, Toyoha Min...
# ...            ...                                                ...
# 9107   Colomeraite                                               None
# 9108        Pomite                                               None
# 9109  Pseudopomite                                               None
# 9110     Shimenite                                               None
# 9111      Dewitite                                               None
#
#                                                 Formula  \
# 0               (Mg,Mn2+)7◻2Mn2+2Zn4(SO4)2(OH)22 · 8H2O
# 1               Na0.5(Al,Mg)6((Si,Al)8O18)(OH)12 · 5H2O
# 2                   (Na,Ca,K)8(Al6Si6O24)(SO4)2Cl · H2O
# 3     [A(D3)G6(Si6O18)(BO3)3X3ZA = Ca, Na, K, Pb or ...
# 4                                Ag1+(Fe2+0.5Sn4+1.5)S4
# ...                                                 ...
# 9107                                        NaTi3+Si2O6
# 9108                     Ca3[V4+5V5+10O37(CO3)] · 37H2O
# 9109                    Ca3.5[V4+6V5+9O37(CO3)] · 29H2O
# 9110                          Tl5Sb21-yAsyS349 ≤ y ≤ 10
# 9111  AgzTl10-x-zPb2xSb42-x-yAsyS680.09 ≤ x ≤ 2.13\n...
#
#                                              IMA status  \
# 0     Approved, 'Grandfathered' (first described pri...
# 1     Approved, 'Grandfathered' (first described pri...
# 2                                              Approved
# 3                                                  None
# 4                                              Approved
# ...                                                 ...
# 9107                      Approved, Pending publication
# 9108                      Approved, Pending publication
# 9109                      Approved, Pending publication
# 9110                      Approved, Pending publication
# 9111                      Approved, Pending publication
#
#                                  IMA Formula  \
# 0                  Mg9Zn4(SO4)2(OH)22 · 8H2O
# 1      Na0.5(Al,Mg)6(Si,Al)8O18(OH)12 · 5H2O
# 2     (Na,Ca,K)8(Si6Al6)O24(SO4)2Cl · 0.5H2O
# 3                                       None
# 4                                       None
# ...                                      ...
# 9107                                    None
# 9108                                    None
# 9109                                    None
# 9110                                    None
# 9111                                    None
#
#                                                  Colour              Streak  \
# 0     Rarely colourless, white, usually light brown ...  White to colorless
# 1     White, light yellow, light green, deep blue to...                None
# 2     Green to yellowish-green, glass-green with a y...               White
# 3                                                  None                None
# 4                                            Gray-brown                None
# ...                                                 ...                 ...
# 9107                                               None                None
# 9108                                               None                None
# 9109                                               None                None
# 9110                                               None                None
# 9111                                               None                None
#
#                                     Lustre              Transparency  \
# 0     Vitreous, Sub-Vitreous, Pearly, Dull  Transparent, Translucent
# 1                               Waxy, Dull               Translucent
# 2                                 Vitreous                      None
# 3                                     None                      None
# 4                                 Metallic                    Opaque
# ...                                    ...                       ...
# 9107                                  None                      None
# 9108                                  None                      None
# 9109                                  None                      None
# 9110                                  None                      None
# 9111                                  None                      None
#
#          Pleochroism  ... Birefringence Dana 7th ed. Hardness Data  \
# 0     Non-pleochroic  ...         0.015         None          None
# 1               None  ...          None         None          None
# 2               None  ...          None         None          None
# 3               None  ...          None         None          None
# 4               None  ...          None         None          None
# ...              ...  ...           ...          ...           ...
# 9107            None  ...          None         None          None
# 9108            None  ...          None         None          None
# 9109            None  ...          None         None          None
# 9110            None  ...          None         None          None
# 9111            None  ...          None         None          None
#
#      Strunz 8th ed.                                    Cell Parameters  \
# 0         6/D.04-20  a = 10.522 Å, b = 9.433 Å, c = 16.443 Åβ = 94.91°
# 1         8/H.18-50          a = 5.17 Å, b = 8.97 Å, c = 24.2 Åβ = 94°
# 2         8/J.09-55                           a = 12.84 Å, c = 32.23 Å
# 3              None                                               None
# 4        2/C.06-160                                               None
# ...             ...                                                ...
# 9107           None  a = 9.70(1) Å, b = 8.88(1) Å, c = 5.30(1) Åβ =...
# 9108           None  a = 12.367(1) Å, b = 12.969(1) Å, c = 22.068(2...
# 9109           None  a = 12.291(2) Å, b = 12.620(1) Å, c = 20.917(3...
# 9110           None  a = 8.1137(5) Å, b = 8.6488(6) Å, c = 21.258(1...
# 9111           None  a = 8.626(2) Å, b = 16.351(3) Å, c = 21.892(4)...
#
#                                            Dana 8th ed.  \
# 0     31.1.4.131 : HYDRATED SULFATES CONTAINING HYDR...
# 1     71.4.2.471 : PHYLLOSILICATES Sheets of Six-Mem...
# 2     76.2.5.1476 : TECTOSILICATES Al-Si Framework2 ...
# 3                                                  None
# 4     2.10.3.22 : SULFIDES10 : AmBnXp, with (m+n):p ...
# ...                                                 ...
# 9107                                               None
# 9108                                               None
# 9109                                               None
# 9110                                               None
# 9111                                               None
#
#                                   Unit Cell V  \
# 0     1,626.04 Å³ (Calculated from Unit Cell)
# 1     1,119.54 Å³ (Calculated from Unit Cell)
# 2     4,601.73 Å³ (Calculated from Unit Cell)
# 3                                        None
# 4                                        None
# ...                                       ...
# 9107    437.04 Å³ (Calculated from Unit Cell)
# 9108  3,368.67 Å³ (Calculated from Unit Cell)
# 9109  2,853.44 Å³ (Calculated from Unit Cell)
# 9110  1,474.08 Å³ (Calculated from Unit Cell)
# 9111  2,963.16 Å³ (Calculated from Unit Cell)
#
#                                                Twinning Isostructural with  \
# 0     Intricately polysynthetically twinned with twi...     Lawsonbauerite
# 1                                                  None               None
# 2                                                  None               None
# 3                                                  None               None
# 4       Twinning is recognized under high magnification      Rhodostannite
# ...                                                 ...                ...
# 9107                                               None               None
# 9108                                               None               None
# 9109                                               None               None
# 9110                                               None               None
# 9111                                               None               None
#
#      Parting
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 9107    None
# 9108    None
# 9109    None
# 9110    None
# 9111    None
#
# [9112 rows x 54 columns]

# %%
df.to_csv('mindat.csv')

# %%
#df = df.loc[df['instance of (p31)'] !='mountain (Q8502)']
#df = df.loc[df['instance of (p31)'] !='human settlement (Q486972)']
#df = df.loc[df['instance of (p31)'] =='mineral species (Q12089225)']

# %%
df.shape
# Out:
# (9112, 54)

# %%
#df['colour'] = df['color'] + df['colour'] #Merging columns into a single column
