# %%
import json
import pandas as pd

from copy import deepcopy

# %%
def to_lower(df, col):
    df[col] = df[col].apply(lambda x: x.lower())
    return df

# %%
def process_df(df):
    df.columns = [x.lower() for x in df.columns]
    df.sort_index(axis=1, inplace=True)
    df.sort_values('mineral_name', inplace=True)
    df = to_lower(df, 'mineral_name')
    mid = df['mineral_name']
    df.drop(labels=['mineral_name'], axis=1,inplace = True)
    df.insert(0, 'mineral_name', mid)
    return df

# %%
def json_to_df(file_path):
    with open(file_path, 'r') as f:
        obj= json.load(f)
    records = []
    for k, v in obj.items():
        temp = deepcopy(v)
        temp['mineral_name'] = k
        records.append(temp)
    df = pd.DataFrame.from_records(records)
    df = process_df(df)
    return df

# %%
def filter_df(df, axis, threshold=30):
    min_count = int((threshold / 100) * df.shape[axis] + 1)
    filtered_df = df.dropna(axis= int(not axis), how='any', thresh=min_count).reset_index(drop=True)
    return filtered_df

# %%
mindat_df = json_to_df('../data/mindat/mindat-7k-all.json')
web_df = json_to_df('../data/webmineral/combined_minerals.json')

# %%
ima_df = pd.read_csv('../data/ima_mineral_list/ima-list.csv', index_col=0)
ima_df = ima_df.rename(columns={'name': 'mineral_name'})
ima_df = process_df(ima_df)

# %%
web_df.drop(web_df.columns[range(1, 134)], axis=1, inplace=True)

# %%
web_df.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4660 entries, 1944 to 1943
# Data columns (total 47 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mineral_name        4660 non-null   object
#  1   axial ratios        3999 non-null   object
#  2   cell dimensions     4409 non-null   object
#  3   chemical formula    4660 non-null   object
#  4   cleavage            3556 non-null   object
#  5   color               4526 non-null   object
#  6   composition         4660 non-null   object
#  7   crystal structure   3013 non-null   object
#  8   crystal system      4624 non-null   object
#  9   dana class          4660 non-null   object
#  10  density             3813 non-null   object
#  11  diaphaneity         3978 non-null   object
#  12  dichroism (e)       194 non-null    object
#  13  dichroism (w)       195 non-null    object
#  14  electron density    4540 non-null   object
#  15  empirical formula   4660 non-null   object
#  16  environment         4121 non-null   object
#  17  fermion index       4660 non-null   object
#  18  forms               631 non-null    object
#  19  fracture            2298 non-null   object
#  20  gladstone-dale      3186 non-null   object
#  21  habit               3228 non-null   object
#  22  hardness            4010 non-null   object
#  23  ima status          4660 non-null   object
#  24  images              4660 non-null   object
#  25  locality            4660 non-null   object
#  26  luminescence        1068 non-null   object
#  27  luster              4137 non-null   object
#  28  magnetism           363 non-null    object
#  29  name origin         4657 non-null   object
#  30  name pronunciation  3573 non-null   object
#  31  optical data        3906 non-null   object
#  32  photoelectric       4659 non-null   object
#  33  pleochroism (x)     665 non-null    object
#  34  pleochroism (y)     623 non-null    object
#  35  pleochroism (z)     572 non-null    object
#  36  radioactivity       4660 non-null   object
#  37  references          4429 non-null   object
#  38  rl anisotrophism    591 non-null    object
#  39  rl bireflectance    166 non-null    object
#  40  rl color            681 non-null    object
#  41  rl pleochroism      353 non-null    object
#  42  see also            4660 non-null   object
#  43  streak              3730 non-null   object
#  44  strunz class        4660 non-null   object
#  45  synonym             3512 non-null   object
#  46  x ray diffraction   4392 non-null   object
# dtypes: object(47)
# memory usage: 1.7+ MB

# %%
mindat_df.info(max_cols=200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6861 entries, 5051 to 849
# Data columns (total 102 columns):
#  #    Column                                Non-Null Count  Dtype
# ---   ------                                --------------  -----
#  0    mineral_name                          6861 non-null   object
#  1    2v                                    1434 non-null   object
#  2    a mixture of                          17 non-null     object
#  3    anisotropism                          417 non-null    object
#  4    approval history                      212 non-null    object
#  5    approval year                         929 non-null    object
#  6    as a commodity                        24 non-null     object
#  7    bireflectance                         94 non-null     object
#  8    birefringence                         538 non-null    object
#  9    cas registry number                   34 non-null     object
#  10   cell parameters                       3313 non-null   object
#  11   class (h-m)                           2296 non-null   object
#  12   cleavage                              2082 non-null   object
#  13   co-first recorded localities          9 non-null      object
#  14   co-type localities                    256 non-null    object
#  15   colour                                3509 non-null   object
#  16   colour in reflected light             436 non-null    object
#  17   comment                               1612 non-null   object
#  18   comments                              1443 non-null   object
#  19   common impurities                     1371 non-null   object
#  20   crystal atlas                         280 non-null    object
#  21   crystal system                        3703 non-null   object
#  22   dana 7th ed.                          435 non-null    object
#  23   dana 8th ed.                          3446 non-null   object
#  24   density                               2638 non-null   object
#  25   dimorph of                            245 non-null    object
#  26   dispersion                            1922 non-null   object
#  27   download                              944 non-null    object
#  28   electrical                            57 non-null     object
#  29   elements listed                       4195 non-null   object
#  30   empirical formulas                    37 non-null     object
#  31   epitaxi comments                      5 non-null      object
#  32   epitaxial minerals                    69 non-null     object
#  33   epitaxy comments                      53 non-null     object
#  34   external links                        3547 non-null   object
#  35   first published                       1487 non-null   object
#  36   first recorded localities             8 non-null      object
#  37   first recorded locality               102 non-null    object
#  38   formula                               4231 non-null   object
#  39   fracture                              1263 non-null   object
#  40   french synonym of                     1 non-null      object
#  41   geological setting                    963 non-null    object
#  42   german name for                       1 non-null      object
#  43   german synonym of                     1 non-null      object
#  44   hardness                              3374 non-null   object
#  45   hardness data                         179 non-null    object
#  46   health risks                          4621 non-null   object
#  47   hey's cim ref.                        3343 non-null   object
#  48   idealised formula                     87 non-null     object
#  49   ima formula                           1907 non-null   object
#  50   ima status                            3710 non-null   object
#  51   ima status notes                      177 non-null    object
#  52   in uv light                           835 non-null    object
#  53   industrial uses                       150 non-null    object
#  54   interestingness                       1 non-null      object
#  55   internal reflections                  139 non-null    object
#  56   ir spectrum                           48 non-null     object
#  57   isostructural with                    340 non-null    object
#  58   lustre                                3097 non-null   object
#  59   magnetism                             61 non-null     object
#  60   member of                             1841 non-null   object
#  61   mindat.org url                        6861 non-null   object
#  62   mineral dealers                       4607 non-null   object
#  63   morphology                            1961 non-null   object
#  64   name                                  3553 non-null   object
#  65   nickel-strunz 10th (pending) ed.      3738 non-null   object
#  66   notes                                 860 non-null    object
#  67   optical extinction                    271 non-null    object
#  68   oxide wt%                             121 non-null    object
#  69   parting                               123 non-null    object
#  70   pleochroism                           1148 non-null   object
#  71   polymorph of                          103 non-null    object
#  72   powder diffraction data               1696 non-null   object
#  73   pronounciation                        635 non-null    object
#  74   ratio                                 2995 non-null   object
#  75   recorded ages                         44 non-null     object
#  76   reference                             1344 non-null   object
#  77   reference list                        4817 non-null   object
#  78   reflectivity                          317 non-null    object
#  79   ri values                             2544 non-null   object
#  80   sample references                     135 non-null    object
#  81   search engines                        6861 non-null   object
#  82   series formula                        5 non-null      object
#  83   setting                               706 non-null    object
#  84   space group                           1937 non-null   object
#  85   special storage/display requirements  59 non-null     object
#  86   specific gravity                      2481 non-null   object
#  87   streak                                2065 non-null   object
#  88   strunz 8th ed.                        3621 non-null   object
#  89   strunz 9th ed.                        91 non-null     object
#  90   surface relief                        2544 non-null   object
#  91   synonym                               15 non-null     object
#  92   synonym of                            59 non-null     object
#  93   tenacity                              1452 non-null   object
#  94   thermal behaviour                     131 non-null    object
#  95   translation gliding                   13 non-null     object
#  96   transparency                          2725 non-null   object
#  97   twinning                              751 non-null    object
#  98   type                                  2897 non-null   object
#  99   type locality                         3174 non-null   object
#  100  unit cell v                           3309 non-null   object
#  101  z                                     2038 non-null   object
# dtypes: object(102)
# memory usage: 5.4+ MB

# %%
ima_df['mineral_name'].head()
# Out:
# 1          abellaite
# 2         abelsonite
# 3    abenakiite-(ce)
# 4       abernathyite
# 5           abhurite
# Name: mineral_name, dtype: object

# %%
web_df[web_df['mineral_name'] == 'abelsonite']
# Out:
#      mineral_name             axial ratios  \
# 1944   abelsonite   a:b:c =0.7589:1:0.6546
#
#                                         cell dimensions chemical formula  \
# 1944   a = 8.44, b = 11.12, c = 7.28, Z = 1; alpha =...     Ni++C31H32N4
#
#          cleavage                                 color  \
# 1944   {111} Good   Pinkish red, Purple, Reddish brown.
#
#                         composition crystal structure  \
# 1944   Molecular Weight = 519.31 gm               NaN
#
#                        crystal system  \
# 1944   TriclinicSpace Group: P1 or P1
#
#                                    dana class  ...  \
# 1944   50.04.09.01 (50)Salts of Organic Acids  ...
#
#                                              references rl anisotrophism  \
# 1944   NAME( Dana8) PHYS. PROP.(Enc. of Minerals,2nd...              NaN
#
#      rl bireflectance rl color rl pleochroism  \
# 1944              NaN      NaN            NaN
#
#                                                see also streak  \
# 1944   Links to other databases for Abelsonite :\n1 ...    NaN
#
#                           strunz class            synonym  \
# 1944   10.CA.20 10 - ORGANIC COMPOUNDS   Nickel Porphyrin
#
#                                       x ray diffraction
# 1944   By Intensity(I/Io): 10.9(1), 3.77(0.8), 7.63(...
#
# [1 rows x 47 columns]

# %%
ima_df.shape
# Out:
# (5739, 7)

# %%
web_df.shape
# Out:
# (4660, 47)

# %%
mindat_df[mindat_df['mineral_name'] == 'abenakiite-(ce)']
# Out:
#          mineral_name   2v a mixture of anisotropism approval history  \
# 4206  abenakiite-(ce)  NaN          NaN          NaN              NaN
#
#      approval year as a commodity bireflectance birefringence  \
# 4206          1991            NaN           NaN           NaN
#
#      cas registry number  ... synonym of tenacity thermal behaviour  \
# 4206                 NaN  ...        NaN  Brittle               NaN
#
#      translation gliding transparency twinning          type  \
# 4206                 NaN          NaN      NaN  Uniaxial (-)
#
#                                           type locality  \
# 4206  ⓘ Poudrette quarry (De-Mix quarry; Demix quarr...
#
#                                   unit cell v  z
# 4206  4,390.93 Å³ (Calculated from Unit Cell)  3
#
# [1 rows x 102 columns]

# %%
common_df[common_df['mineral_name'] == 'aanerodite']
# Out:
# Empty DataFrame
# Columns: [mineral_name, country, first ref, formula, ima status_x, ima year, second ref, axial ratios, cell dimensions, chemical formula, cleavage, color, composition, crystal structure, crystal system, dana class, density, diaphaneity, dichroism (e), dichroism (w), electron density, empirical formula, environment, fermion index, forms, fracture, gladstone-dale, habit, hardness, ima status_y, images, locality, luminescence, luster, magnetism, name origin, name pronunciation, optical data, photoelectric, pleochroism (x), pleochroism (y), pleochroism (z), radioactivity, references, rl anisotrophism, rl bireflectance, rl color, rl pleochroism, see also, streak, strunz class, synonym, x ray diffraction]
# Index: []
#
# [0 rows x 53 columns]

# %%
mindat_df.shape
# Out:
# (6861, 102)

# %%
common_df = pd.merge(ima_df, web_df, how='outer', on=['mineral_name'])
# common_df = pd.merge(ima_df, mindat_df, how='outer', on=['mineral_name'])

# %%
common_df.head(10)
# Out:
#       mineral_name         country  \
# 0        abellaite           Spain
# 1       abelsonite             USA
# 2  abenakiite-(ce)          Canada
# 3     abernathyite             USA
# 4         abhurite    Saudi Arabia
# 5       abramovite          Russia
# 6   abswurmbachite          Greece
# 7           abuite           Japan
# 8        acanthite  Czech Republic
# 9        acetamide         Ukraine
#
#                                            first ref  \
# 0     European Journal of Mineralogy  29 (2017), 915
# 1              American Mineralogist  63 (1978), 930
# 2              Canadian Mineralogist  32 (1994), 843
# 3               American Mineralogist  41 (1956), 82
# 4              Canadian Mineralogist  23 (1985), 233
# 5  Zapiski Rossiyskogo Mineralogicheskogo Obshche...
# 6  Neues Jahrbuch für Mineralogie Abhandlungen  1...
# 7  Journal of Mineralogical and Petrological Scie...
# 8      Annalen der Physik und Chemie  95 (1855), 462
# 9  Zapiski Vsesoyuznogo Mineralogicheskogo Obshch...
#
#                              formula ima status_x  ima year  \
# 0                    NaPb2(CO3)2(OH)            A  2014-111
# 1                         NiC31H32N4            A  1975-013
# 2  Na26Ce6(Si6O18)(PO4)6(CO3)6(SO2)O            A  1991-054
# 3                  K(UO2)(AsO4)·3H2O            G      1956
# 4                 Sn2+21O6(OH)14Cl16            A  1983-061
# 5                        Pb2SnInBiS7            A  2006-016
# 6                  Cu2+Mn3+6O8(SiO4)            A  1990-007
# 7                      CaAl2(PO4)2F2            A  2014-084
# 8                               Ag2S            G      1855
# 9                           CH3CONH2            A  1974-039
#
#                                          second ref             axial ratios  \
# 0                                               NaN                      NaN
# 1           American Mineralogist  102 (2017), 1129   a:b:c =0.7589:1:0.6546
# 2                                               NaN          a:c = 1:1.23367
# 3            American Mineralogist  49 (1964), 1578          a:c = 1:1.26638
# 4             Canadian Mineralogist  41 (2003), 659          a:c = 1:4.39508
# 5                                               NaN   a:b:c =4.0554:1:1.0103
# 6                                               NaN          a:c = 1:1.97172
# 7                                               NaN                      NaN
# 8  Superlattices and Microstructures  83 (2015), 35   a:b:c =0.6101:1:1.1343
# 9     Journal of Physical Chemistry  96 (1992), 668          a:c = 1:1.18006
#
#                                      cell dimensions  \
# 0                                                NaN
# 1   a = 8.44, b = 11.12, c = 7.28, Z = 1; alpha =...
# 2   a = 16.018, c = 19.761, Z = 3; V = 4,390.93 D...
# 3   a = 7.17, c = 9.08, Z = 2; V = 466.79 Den(Cal...
# 4   a = 10.018, c = 44.03, Z = 21; V = 3,826.85 D...
# 5   a = 23.4, b = 5.77, c = 5.83, Z = 4; alpha = ...
# 6   a = 9.406, c = 18.546, Z = 8; V = 1,640.82 De...
# 7                                                NaN
# 8   a = 4.229, b = 6.931, c = 7.862, Z = 4; beta ...
# 9   a = 11.44, c = 13.5, Z = 18; V = 1,530.09 Den...
#
#                          chemical formula  ...  \
# 0                                     NaN  ...
# 1                            Ni++C31H32N4  ...
# 2   Na26REE6(SiO3)6(PO4)6(CO3)6(S++++O2)O  ...
# 3                     K(UO2)(AsO4)•4(H2O)  ...
# 4                            Sn3O(OH)2Cl2  ...
# 5                             Pb2SnInBiS7  ...
# 6                         Cu++Mn+++6SiO12  ...
# 7                                     NaN  ...
# 8                                    Ag2S  ...
# 9                            CO(CH3)(NH2)  ...
#
#                                           references  \
# 0                                                NaN
# 1   NAME( Dana8) PHYS. PROP.(Enc. of Minerals,2nd...
# 2   NAME( MinRec) PHYS. PROP.(37th List of New Mi...
# 3   NAME( AntBidBlaNic4) PHYS. PROP.(Enc. of Mine...
# 4   NAME( Dana8) PHYS. PROP.(Enc. of Minerals,2nd...
# 5   NAME( Geology of Ore Deposits, v50:551) PHYS....
# 6   NAME( AntBidBlaNic2) PHYS. PROP.(37th List of...
# 7                                                NaN
# 8   NAME( Duda&Rejl90) PHYS. PROP.(Enc. of Minera...
# 9   NAME( Dana8) PHYS. PROP.(Enc. of Minerals,2nd...
#
#                    rl anisotrophism rl bireflectance  \
# 0                               NaN              NaN
# 1                               NaN              NaN
# 2                               NaN              NaN
# 3                               NaN              NaN
# 4                               NaN              NaN
# 5   Distinct without color effects.            Weak.
# 6                               NaN              NaN
# 7                               NaN              NaN
# 8                             Weak.            None.
# 9                               NaN              NaN
#
#                             rl color rl pleochroism  \
# 0                                NaN            NaN
# 1                                NaN            NaN
# 2                                NaN            NaN
# 3                                NaN            NaN
# 4                                NaN            NaN
# 5   White with a yellowish gray hue.            NaN
# 6                                NaN            NaN
# 7                                NaN            NaN
# 8                                NaN          None.
# 9                                NaN            NaN
#
#                                             see also           streak  \
# 0                                                NaN              NaN
# 1   Links to other databases for Abelsonite :\n1 ...              NaN
# 2   Links to other databases for Abenakiite-(Ce) ...            white
# 3   Links to other databases for Abernathyite :\n...           yellow
# 4   Links to other databases for Abhurite :\n1 - ...            white
# 5   Links to other databases for Abramovite :\n1 ...            black
# 6   Links to other databases for Abswurmbachite :...   brownish black
# 7                                                NaN              NaN
# 8   Links to other databases for Acanthite :\n1 -...    shining black
# 9   Links to other databases for Acetamide :\n1 -...            white
#
#                                         strunz class            synonym  \
# 0                                                NaN                NaN
# 1                    10.CA.20 10 - ORGANIC COMPOUNDS   Nickel Porphyrin
# 2               09.CK.10 09 - SILICATES (Germanates)         ICSD 79159
# 3     08.EB.15 08 - PHOSPHATES, ARSENATES, VANADATES         ICSD 15481
# 4                              03.DA.30 03 - HALIDES         ICSD 15581
# 5   02.HF.25a 02 - SULFIDES and SULFOSALTS (sulfi...        IMA2006-016
# 6               09.AG.05 09 - SILICATES (Germanates)         ICSD 71823
# 7                                                NaN                NaN
# 8   02.BA.30a 02 - SULFIDES and SULFOSALTS (sulfi...         ICSD 30445
# 9                    10.AA.20 10 - ORGANIC COMPOUNDS         Ethanamide
#
#                                    x ray diffraction
# 0                                                NaN
# 1   By Intensity(I/Io): 10.9(1), 3.77(0.8), 7.63(...
# 2   By Intensity(I/Io): 2.674(1), 3.773(0.9), 8.0...
# 3   By Intensity(I/Io): 9.14(1), 3.34(0.8), 3.84(...
# 4   By Intensity(I/Io): 2.5313(1), 2.8915(0.7), 4...
# 5   By Intensity(I/Io): 3.9(1), 3.84(0.71), 5.9(0...
# 6   By Intensity(I/Io): 2.702(1), 1.6507(0.3), 2....
# 7                                                NaN
# 8   By Intensity(I/Io): 2.606(1), 2.44(0.8), 2.38...
# 9   By Intensity(I/Io): 5.7(1), 3.54(0.91), 2.86(...
#
# [10 rows x 53 columns]

# %%
common_df[['ima status_y', 'ima status_x']].head(20)
# Out:
#                          ima status_y ima status_x
# 0                                 NaN            A
# 1                   Approved IMA 1975            A
# 2                   Approved IMA 1994            A
# 3        Valid Species (Pre-IMA) 1956            G
# 4                   Approved IMA 1983            A
# 5    Approved IMA 2006 (Dana # Added)            A
# 6                   Approved IMA 1991            A
# 7                                 NaN            A
# 8        Valid Species (Pre-IMA) 1855            G
# 9                   Approved IMA 1975            A
# 10                                NaN            A
# 11                                NaN           Rn
# 12                                NaN            A
# 13                                NaN            A
# 14       Valid Species (Pre-IMA) 1794           Rd
# 15                  Approved IMA 1987            A
# 16                                NaN            A
# 17       Valid Species (Pre-IMA) 1866            G
# 18   Approved IMA 1999 (Dana # Added)            A
# 19                                NaN            A

# %%
fil_df = filter_df(mindat_df, axis=0, threshold=3)
fil_df = filter_df(fil_df, axis=1, threshold=10)

# %%
fil_df.shape
# Out:
# (4351, 67)

# %%
for col in mindat_df.columns:
    print(col)
# Out:
# mineral_name
# 2v
# a mixture of
# anisotropism
# approval history
# approval year
# as a commodity
# bireflectance
# birefringence
# cas registry number
# cell parameters
# class (h-m)
# cleavage
# co-first recorded localities
# co-type localities
# colour
# colour in reflected light
# comment
# comments
# common impurities
# crystal atlas
# crystal system
# dana 7th ed.
# dana 8th ed.
# density
# dimorph of
# dispersion
# download
# electrical
# elements listed
# empirical formulas
# epitaxi comments
# epitaxial minerals
# epitaxy comments
# external links
# first published
# first recorded localities
# first recorded locality
# formula
# fracture
# french synonym of
# geological setting
# german name for
# german synonym of
# hardness
# hardness data
# health risks
# hey's cim ref.
# idealised formula
# ima formula
# ima status
# ima status notes
# in uv light
# industrial uses
# interestingness
# internal reflections
# ir spectrum
# isostructural with
# lustre
# magnetism
# member of
# mindat.org url
# mineral dealers
# morphology
# name
# nickel-strunz 10th (pending) ed.
# notes
# optical extinction
# oxide wt%
# parting
# pleochroism
# polymorph of
# powder diffraction data
# pronounciation
# ratio
# recorded ages
# reference
# reference list
# reflectivity
# ri values
# sample references
# search engines
# series formula
# setting
# space group
# special storage/display requirements
# specific gravity
# streak
# strunz 8th ed.
# strunz 9th ed.
# surface relief
# synonym
# synonym of
# tenacity
# thermal behaviour
# translation gliding
# transparency
# twinning
# type
# type locality
# unit cell v
# z
