# %%
import os
import json
import pandas as pd
import numpy as np
from pprint import pprint
from copy import deepcopy

# %%
global_dict = {}

for file in os.listdir('../data/webmineral'):
    if file.endswith('json') and not file.startswith('webmineral'):
        print(file)
        with open(f'../data/webmineral/{file}', 'r') as f:
            temp= json.load(f)
            global_dict.update(temp)
# Out:
# combined_minerals.json

# %%
print(len(global_dict))
attr = [len(v) for v in global_dict.values()]
print(np.mean(attr))
print(np.median(attr))
# Out:
# 4660
# 32.21738197424893
# 33.0

# %%
records = []
for k, v in global_dict.items():
    temp = deepcopy(v)
    temp['Mineral name'] = k
    records.append(temp)

# %%
df = pd.DataFrame.from_records(records)
df=df.set_index('Mineral name')
df.info(max_cols = 200)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4660 entries, Natanite to Krutaite
# Data columns (total 179 columns):
#  #    Column                                                                     Non-Null Count  Dtype
# ---   ------                                                                     --------------  -----
#  0    Chemical Formula                                                           4660 non-null   object
#  1    Composition                                                                4660 non-null   object
#  2    Empirical Formula                                                          4660 non-null   object
#  3    Environment                                                                4121 non-null   object
#  4    IMA Status                                                                 4660 non-null   object
#  5    Locality                                                                   4660 non-null   object
#  6    Name Origin                                                                4657 non-null   object
#  7    Name Pronunciation                                                         3573 non-null   object
#  8    Synonym                                                                    3512 non-null   object
#  9    Images                                                                     4660 non-null   object
#  10   Cell Dimensions                                                            4409 non-null   object
#  11   Crystal System                                                             4624 non-null   object
#  12   X Ray Diffraction                                                          4392 non-null   object
#  13   Crystal Structure                                                          3013 non-null   object
#  14   Cleavage                                                                   3556 non-null   object
#  15   Color                                                                      4526 non-null   object
#  16   Density                                                                    3813 non-null   object
#  17   Diaphaneity                                                                3978 non-null   object
#  18   Hardness                                                                   4010 non-null   object
#  19   Luster                                                                     4137 non-null   object
#  20   Gladstone-Dale                                                             3186 non-null   object
#  21   Optical Data                                                               3906 non-null   object
#  22   Electron Density                                                           4540 non-null   object
#  23   Fermion Index                                                              4660 non-null   object
#  24   Photoelectric                                                              4659 non-null   object
#  25   Radioactivity                                                              4660 non-null   object
#  26   Dana Class                                                                 4660 non-null   object
#  27   Strunz Class                                                               4660 non-null   object
#  28   References                                                                 4429 non-null   object
#  29   See Also                                                                   4660 non-null   object
#  30   Axial Ratios                                                               3999 non-null   object
#  31   Streak                                                                     3730 non-null   object
#  32   Fracture                                                                   2298 non-null   object
#  33   Habit                                                                      3228 non-null   object
#  34   Luminescence                                                               1068 non-null   object
#  35     (71.02)with 2                                                            66 non-null     object
#  36   Forms                                                                      631 non-null    object
#  37   Pleochroism (x)                                                            665 non-null    object
#  38   Pleochroism (z)                                                            572 non-null    object
#  39     08.DM -With large and medium-sized cations, (OH, etc.)                   12 non-null     object
#  40     04.D - Metal                                                             183 non-null    object
#  41     (15.02)where A+m B++n (XO3)p · x(H2O), (m+n)                             6 non-null      object
#  42     08.DK -With large and medium-sized cations, (OH, etc.)                   15 non-null     object
#  43   Dichroism (e)                                                              194 non-null    object
#  44   Dichroism (w)                                                              195 non-null    object
#  45   Pleochroism (y)                                                            623 non-null    object
#  46     08.BB -With only medium-sized cations, (OH, etc.)                        42 non-null     object
#  47     04.C - Metal                                                             81 non-null     object
#  48   Magnetism                                                                  363 non-null    object
#  49   RL Anisotrophism                                                           591 non-null    object
#  50     08.EB -UO2                                                               41 non-null     object
#  51     (02.04)where Am Bn Xp, with (m+n)                                        38 non-null     object
#  52     02.B - Metal Sulfides, M                                                 90 non-null     object
#  53   RL Color                                                                   681 non-null    object
#  54     08.BO -With only large cations, (OH, etc.)                               14 non-null     object
#  55     03.AA -M                                                                 25 non-null     object
#  56     (03.01.01)Colusite Group (Isometric                                      4 non-null      object
#  57     02.C - Metal Sulfides, M                                                 106 non-null    object
#  58     (07.05.01)Humite group (Tetragonal                                       4 non-null      object
#  59     (06.02.01)Brucite group (Rhombohedral                                    5 non-null      object
#  60     (71.01)with 1                                                            30 non-null     object
#  61     09.FA -Tektosilicates without additional non-tetrahedral anions, (Al,B)  38 non-null     object
#  62     08.DC -With only medium-sized cations, (OH, etc.)                        45 non-null     object
#  63     (02.08)where Am Bn Xp, with (m+n)                                        67 non-null     object
#  64     (02.08.20)Tsumoite Group (Trigonal                                       5 non-null      object
#  65     02.D - Metal Sulfides, M                                                 66 non-null     object
#  66     02.DC -Variable M                                                        22 non-null     object
#  67     08.CE -With only medium-sized cations, RO4                               33 non-null     object
#  68   RL Bireflectance                                                           166 non-null    object
#  69     08.CH -With large and medium-sized cations, RO4                          18 non-null     object
#  70   RL Pleochroism                                                             353 non-null    object
#  71     (02.08.11)Nickeline Group (Hexagonal                                     13 non-null     object
#  72     04.B - Metal                                                             36 non-null     object
#  73     (02.12)where Am Bn Xp, with (m+n)                                        88 non-null     object
#  74     02.E - Metal Sulfides, M                                                 85 non-null     object
#  75     02.EC -M                                                                 6 non-null      object
#  76     08.BH -With medium-sized and large cations, (OH,etc.)                    39 non-null     object
#  77     03.BB -M                                                                 7 non-null      object
#  78     (29.06.08)Hexahydrite Group (Space Group                                 6 non-null      object
#  79     (02.10)where Am Bn Xp, with (m+n)                                        28 non-null     object
#  80     (02.10.01)Linnaeite Group (Isometric                                     19 non-null     object
#  81     02.DA -M                                                                 29 non-null     object
#  82     08.CG -With large and medium-sized cations, RO4                          36 non-null     object
#  83     (40.02.02)Fairfieldite Subgroup (Triclinic                               10 non-null     object
#  84     (14.01.01)Calcite Group (Trigonal                                        8 non-null      object
#  85     (14.01.03)Aragonite Group (Orthorhombic                                  4 non-null      object
#  86     08.EC -UO2                                                               20 non-null     object
#  87     (31.01)where (A+ B++)m (XO4)p Zq·x(H2O), where m                         11 non-null     object
#  88     (71.04)interlayered 1                                                    21 non-null     object
#  89     (02.08.01)Galena Group (Isometric                                        9 non-null      object
#  90     (02.12.02)Marcasite Group (Orthorhombic                                  13 non-null     object
#  91     02.EB -M                                                                 63 non-null     object
#  92     (16b.03)where Am Bn (XO3)p Zq · x(H2O), (m+n)                            5 non-null      object
#  93     (71.03)with 2                                                            14 non-null     object
#  94     (02.09)where Am Bn Xp, with (m+n)                                        51 non-null     object
#  95     08.BN -With only large cations, (OH, etc.)                               27 non-null     object
#  96     08.DJ -With large and medium-sized cations, (OH, etc.)                   12 non-null     object
#  97     (02.08.02)Sphalerite Group (Isometric                                    7 non-null      object
#  98     (02.03)where Am Bn Xp, with (m+n)                                        10 non-null     object
#  99     (02.05)where Am Bn Xp, with (m+n)                                        16 non-null     object
#  100    08.BL -With medium-sized and large cations, (OH, etc.)                   41 non-null     object
#  101    (02.11)where Am Bn Xp, with (m+n)                                        25 non-null     object
#  102    08.EA -UO2                                                               7 non-null      object
#  103    (02.12.04)Arsenopyrite Group (Monoclinic                                 6 non-null      object
#  104    05.EA -UO2                                                               6 non-null      object
#  105    02.DB -M                                                                 15 non-null     object
#  106    (02.06)where Am Bn Xp, with (m+n)                                        18 non-null     object
#  107    08.DH -With large and medium-sized cations, (OH, etc.)                   45 non-null     object
#  108    (02.09.02)Stannite Group (Tetragonal                                     11 non-null     object
#  109    (16b.02)where (A)m (B)n (XO3)p Zq · x(H2O), with (m+n)                   9 non-null      object
#  110    (02.11.07)Tetradymite Group (Trigonal                                    7 non-null      object
#  111    04.A - Metal                                                             22 non-null     object
#  112    04.AA -Cation                                                            3 non-null      object
#  113    08.CD -With only medium-sized cations, RO4                               12 non-null     object
#  114    08.DF -With only medium-sized cations, (OH,etc.)                         12 non-null     object
#  115    08.BD -With only medium-sized cations, (OH, etc.)                        9 non-null      object
#  116    08.BM -With medium-sized and large cations, (OH, etc.)                   5 non-null      object
#  117    (03.08.10)Pavonite Group (Monoclinic                                     8 non-null      object
#  118    Pearceite-T2ac - Suggested nomenclature from AmMin v92                   1 non-null      object
#  119    (02.12.01)Pyrite Group (Isometric                                        19 non-null     object
#  120    (29.06.07)Chalchanthite Group (Triclinic                                 4 non-null      object
#  121    (02.07)where Am Bn Xp, with (m+n)                                        12 non-null     object
#  122    (02.07.01)Pentalndite Group (Isometric                                   6 non-null      object
#  123    04.AB -M                                                                 12 non-null     object
#  124    (16b.04)where (A)m (B)n (XO3)p Zq · x(H2O), with (m+n)                   6 non-null      object
#  125    08.DL -With large and medium-sized cations, (OH, etc.)                   20 non-null     object
#  126    08.CC -With only medium-sized cations, RO4                               7 non-null      object
#  127    (02.06.02)Joseite Group (Trigonal                                        8 non-null      object
#  128    (29.06.10)Melanterite Group (Heptahydrates, Monoclinic                   6 non-null      object
#  129    08.DB -With only medium-sized cations, (OH, etc.)                        16 non-null     object
#  130    (03.06.20)Fuloppite Group (Monoclinc                                     5 non-null      object
#  131    08.DD -With only medium-sized cations, (OH, etc.)                        12 non-null     object
#  132    (04.04.01)Rutile group (Tetragonal                                       9 non-null      object
#  133    08.BC -With only medium-sized cations, (OH, etc.)                        5 non-null      object
#  134    Polybasite-T2ac - Suggested nomenclature from AmMin v92                  1 non-null      object
#  135    (38.04.11)Zenotime Group (Tetragonal                                     8 non-null      object
#  136    (16b.06.02)Sjorgrenite-Hydrotalcite Group (Hydrotalcite Subgroup         5 non-null      object
#  137    08.BE -With only medium-sized cations, (OH, etc.)                        26 non-null     object
#  138    05.ED -UO2                                                               10 non-null     object
#  139    08.CB -With only medium-sized cations, RO4                               16 non-null     object
#  140    (02.08.07)Wurtzite Group (Hexagonal                                      4 non-null      object
#  141    (16b.06.03)Sjorgrenite-Hydrotalcite Group (Hydrotalcite Subgroup         3 non-null      object
#  142    04.AC -M                                                                 7 non-null      object
#  143    (02.09.01)Chalcopyrite Group (Tetragonal                                 6 non-null      object
#  144    (40.02.03)Roselite Subgroup (Monoclinic                                  5 non-null      object
#  145    (04.03.01)Corundum-Hematite group (Rhombohedral                          5 non-null      object
#  146    05.EB -UO2                                                               4 non-null      object
#  147    (41.01)where (A++)m (XO4)p Zq, with m                                    8 non-null      object
#  148    08.DG -With large and medium-sized cations, (OH, etc.)                   6 non-null      object
#  149    08.BF -With medium-sized and large cations, (OH, etc.)                   20 non-null     object
#  150    03.AB -M                                                                 11 non-null     object
#  151    (30.01)where (A B)m (XO4)p Zq where m                                    18 non-null     object
#  152    (16b.01)where (A)m (B)n (XO3)p Zq, with (m+n)                            13 non-null     object
#  153    08.DE -With only medium-sized cations, (OH, etc.)                        8 non-null      object
#  154    05.EE -UO2                                                               2 non-null      object
#  155    (02.12.14)Melonite Group (Trigonal                                       7 non-null      object
#  156    02.EA -M                                                                 16 non-null     object
#  157    (16b.06.01)Sjorgrenite-Hydrotalcite Group (Sojogrenite Subgroup          4 non-null      object
#  158    (02.11.02)Stibnite Group (Orthorhombic                                   4 non-null      object
#  159    (06.03.07)Wickmanite group (Tetragonal                                   4 non-null      object
#  160    (15.03)where A+m B++n (XO3)p · x(H2O), (m+n)                             11 non-null     object
#  161    08.BG -With medium-sized and large cations, (OH, etc.)                   13 non-null     object
#  162    04.E - Metal                                                             3 non-null      object
#  163    04.EA -Oxides with metal                                                 3 non-null      object
#  164    08.CF -With large and medium-sized cations, RO4                          5 non-null      object
#  165    (02.01)where Am Xp, with m                                               6 non-null      object
#  166    (03.02.05)Hauchecornite Group, Complex Ni sulfides (Tetragonal           5 non-null      object
#  167    (03.03.06)Tetrahedrite Group (Isometric                                  7 non-null      object
#  168    (25.06.02)Boracite Group (Trigonal                                       2 non-null      object
#  169    03.AC -M                                                                 5 non-null      object
#  170    (02.02)where Am Bn Xp, with (m+n)                                        9 non-null      object
#  171    (24.02.01)Ludwigite Group (Space Group                                   6 non-null      object
#  172    05.EC -UO2                                                               3 non-null      object
#  173    03.BA -M                                                                 2 non-null      object
#  174    (14.02.01)Dolomite Group (Trigonal                                       4 non-null      object
#  175    05.EF -UO2                                                               1 non-null      object
#  176    (25.06.01)Boracite Group (Orthorhombic                                   3 non-null      object
#  177    (38.04.03)Monazite Group (Monoclinic                                     7 non-null      object
#  178    03.BC -M                                                                 1 non-null      object
# dtypes: object(179)
# memory usage: 6.4+ MB

# %%
copy_df = df.copy()

# %%
row_remove_perc = 10.0
min_count = int((row_remove_perc / 100) * copy_df.shape[1] + 1)
copy_df.dropna(axis=0, how='any', thresh=min_count, inplace=True)
copy_df.reset_index(drop=True, inplace=True)

# %%
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4644 entries, 0 to 4643
# Columns: 179 entries, Chemical Formula to   03.BC -M
# dtypes: object(179)
# memory usage: 6.3+ MB

# %%
col_remove_perc = 30.0
min_count = int((col_remove_perc / 100) * copy_df.shape[0] + 1)
copy_df.dropna(axis=1, how='any', thresh=min_count, inplace=True)

# %%
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4644 entries, 0 to 4643
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Chemical Formula    4644 non-null   object
#  1   Composition         4644 non-null   object
#  2   Empirical Formula   4644 non-null   object
#  3   Environment         4119 non-null   object
#  4   IMA Status          4644 non-null   object
#  5   Locality            4644 non-null   object
#  6   Name Origin         4641 non-null   object
#  7   Name Pronunciation  3570 non-null   object
#  8   Synonym             3507 non-null   object
#  9   Images              4644 non-null   object
#  10  Cell Dimensions     4409 non-null   object
#  11  Crystal System      4608 non-null   object
#  12  X Ray Diffraction   4392 non-null   object
#  13  Crystal Structure   3013 non-null   object
#  14  Cleavage            3556 non-null   object
#  15  Color               4526 non-null   object
#  16  Density             3813 non-null   object
#  17  Diaphaneity         3978 non-null   object
#  18  Hardness            4010 non-null   object
#  19  Luster              4137 non-null   object
#  20  Gladstone-Dale      3186 non-null   object
#  21  Optical Data        3890 non-null   object
#  22  Electron Density    4540 non-null   object
#  23  Fermion Index       4644 non-null   object
#  24  Photoelectric       4643 non-null   object
#  25  Radioactivity       4644 non-null   object
#  26  Dana Class          4644 non-null   object
#  27  Strunz Class        4644 non-null   object
#  28  References          4418 non-null   object
#  29  See Also            4644 non-null   object
#  30  Axial Ratios        3999 non-null   object
#  31  Streak              3730 non-null   object
#  32  Fracture            2298 non-null   object
#  33  Habit               3228 non-null   object
# dtypes: object(34)
# memory usage: 1.2+ MB
