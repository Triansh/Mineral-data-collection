# %%
import pandas as pd
import json
import os
from collections import defaultdict

os.chdir('C:\\Users\\arvgoyal\Python Codes\IRE Project\Data Cleaning\data')

# %%
#df = pd.read_json('combined_minerals.json')
with open('combined_minerals.json') as webMinJsn:
    webMin_dic = json.load(webMinJsn)
    
with open('mindat.json') as minDatJsn:
    minDat_dic = json.load(minDatJsn)    

webMin_dic['Natanite'].keys()
minDat_dic.keys()
# Out:
# dict_keys(['Torreyite', 'Tosudite', 'Tounkite', 'Tourmaline', 'Toyohaite', 'Trabzonite', 'Tranquillityite', 'Traskite', 'Treasurite', 'Trechmannite', 'Trembathite', 'Tremolite', 'Trevorite', 'Trögerite', 'Triangulite', 'Tridymite', 'Trigonite', 'Trikalsilite', 'Trimerite', 'Trimounsite-(Y)', 'Triphylite', 'Triplite', 'Triploidite', 'Trippkeite', 'Tripuhyite', 'Tristramite', 'Tritomite-(Ce)', 'Tritomite-(Y)', 'Trogtalite', 'Troilite', 'Trolleite', 'Trona', 'Trüstedtite', 'Truscottite', 'Tsaregorodtsevite', 'Tschermakite', 'Tschermigite', 'Tschernichite', 'Tsnigriite', 'Tsumcorite', 'Tsumebite', 'Tsumoite', 'Tučekite', 'Tugarinovite', 'Tugtupite', 'Tuhualite', 'Tulameenite', 'Tuliokite', 'Tundrite-(Ce)', 'Tundrite-(Nd)', 'Tunellite', 'Tungstenite', 'Tungstibite', 'Tungstic Ochre', 'Tungstite', 'Tungusite', 'Tunisite', 'Tuperssuatsiaite', 'Turanite', 'Turneaureite', 'Turquoise', 'Tuscanite', 'Tusionite', 'Tuzlaite', 'Tvalchrelidzeite', 'Tvedalite', 'Tveitite-(Y)', 'Twinnite', 'Tychite', 'Tyretskite', 'Tyrolite', 'Tyrrellite', 'Tyuyamunite', 'Tangeite', 'U-Galena', 'Uchucchacuaite', 'Uddevallite', 'Udokanite', 'Uduminelite', 'Ugrandite', 'Uhligite', 'Uhligite (of Cornu)', 'Uigite', 'Uintahite', 'Uklonskovite', 'Ulexite', 'Ullmannite', 'Ulmite', 'Ulrichite', 'Ulvöspinel', 'Umangite', 'Umbite', 'Umbozerite', 'Umohoite', 'Mangano-mangani-ungarettiite', 'Ungemachite', 'Upalite', 'Uralborite', 'Uralite', 'Uralolite', 'Uramphite', 'Urancalcarite', 'Uraninite', 'Uranmicrolite (of Hogarth 1977)', 'Uranoanatase', 'Uranocircite-II', 'Uranophane-β', 'Uranophane-α', 'Uranopilite', 'Uranopolycrase', 'Uranosilite', 'Uranospathite', 'Uranosphaerite', 'Uranospinite', 'Uranothorianite', 'Uranotungstite', 'Uranpyrochlore (of Hogarth 1977)', 'Urea', 'Uricite', 'Ursilite', 'Urvantsevite', 'Usovite', 'Ussingite', 'Ustarasite', 'Uvanite', 'Uvarovite', 'Fluor-uvite-Uvite Series', 'Uytenbogaardtite', 'Uzonite', 'Ushkovite', 'Vanadiorutile', 'Vaalite', 'Vabanite', 'Vaesite', 'Valencianite', 'Valentinite', 'Valleriite', 'Valuevite', 'Vanadinbronzite', 'Vanadinite', 'Vanadio-laumontite', 'Vanadiolite', 'Vanadium-bearing Aegirine', 'Vanalite', 'Vandenbrandeite', 'Vandendriesscheite', 'Vandiestite', 'Vanmeersscheite', 'Vanodiochrome spinel', 'Vanoxite', 'Vantasselite', 'Vanthoffite', 'Vanuralite', 'Vanuranylite', 'Vanuxemite', 'Varennesite', 'Variscite', 'Varlamoffite', 'Varulite', 'Vashegyite', 'Vasilite', 'Vaterite', 'Vaughanite', 'Vauquelinite', 'Vauxite', 'Veatchite-A', 'Veatchite', 'Veenite', 'Velikite', 'Verdelite', 'Vermiculite', 'Vernadite', 'Verplanckite', 'Versiliaite', 'Vertumnite', 'Vésigniéite', 'Veszelyite', 'Vigezzite', 'Viitaniemiite', 'Vikingite', 'Villamanínite', 'Villiaumite', 'Villyaellenite', 'Vimsite', 'Vincentite', 'Vinciennite', 'Vinogradovite', 'Violarite', 'Virgilite', 'Viséite', 'Vishnevite', 'Vismirnovite', 'Vistepite', 'Vitusite-(Ce)', 'Vivianite', 'Vladimirite', 'Vlasovite', 'Vochtenite', 'Voggite', 'Voglite', 'Volborthite', 'Volkonskoite', 'Volkovskite', 'Voltaite', 'Voltzite', 'Volynskite', 'Vonbezingite', 'Vonsenite', 'Vorobyevite', 'Vosgite', 'Vozhminite', 'Vrbaite', 'Vuagnatite', 'Vulcanite', 'Vulpinite', 'Vunonnemite', 'Vuonnemite', 'Vuorelainenite', 'Vyacheslavite', 'Vyalsovite', 'Väyrynenite', 'Vysotskite', 'Vyuntspakhkite-(Y)', 'Vesuvianite', 'Wackenrodite', 'Wad', 'Wadalite', 'Wadeite', 'Wadsleyite', 'Wagnerite', 'Wairakite', 'Wairauite', 'Wakabayashilite', 'Wakefieldite-(Ce)', 'Wakefieldite-(Y)', 'Walentaite', 'Wallisite', 'Wallkilldellite', 'Walpurgite', 'Walstromite', 'Walthierite', 'Wapplerite', 'Wardite', 'Wardsmithite', 'Warikahnite', 'Warwickite', 'Watanabeite', 'Watkinsonite', 'Wattersite', 'Wattevilleite', 'Abbecasite', 'Asbeferrite', 'Asbestite', 'Asbestoîde', 'Asbestus', 'Earthy Cobalt', 'Picroallumogene', 'Acanite', 'Asterite', 'Halochalzit', 'Halochalcite', 'Aetheriastite', 'Attacolite', 'Augite-enstatite', 'Basaltine', 'Orichalcite', 'Buratite', 'Risséite', 'Messingite', 'Messingblüthe', 'Blue Calamine', ' ...

# %%
#for k in webMin_dic.keys():
#    print (len(webMin_dic[k].keys()))

all_mnrl = set()
mindat_mnrl = set()
webmin_mnrl = set()

for mnrl in webMin_dic.keys():
    all_mnrl.add(mnrl.lower())
    webmin_mnrl.add(mnrl.lower())
    
for mnrl in minDat_dic.keys():
    all_mnrl.add(mnrl.lower())
    mindat_mnrl.add(mnrl.lower())

# %%
print(len(all_mnrl))
print(len(webmin_mnrl))
print(len(mindat_mnrl))
# Out:
# 9609
# 4660
# 9112

# %%
attr_dic  = defaultdict(lambda:defaultdict(list))

#attr_dic['Name Pronunciation'][1]=     ['webMin','Name Pronunciation']
attr_dic['Synonym'][1]=                ['webMin','Synonym']
attr_dic['Name Origin'][1]=            ['webMin','Name Origin']
attr_dic['Name Origin'][2]=            ['minDat','Name']
attr_dic['Formula'][1]=                ['webMin','Chemical Formula']
attr_dic['Formula'][2]=                ['minDat','Formula']
attr_dic['Formula'][3]=                ['minDat','IMA Formula']
attr_dic['Empirical Formula'][1]=      ['webMin','Empirical Formula']
attr_dic['IMA Status'][1]=             ['webMin','IMA Status']
attr_dic['IMA Status'][2]=             ['minDat','IMA status']
attr_dic['Approval History'][1]=       ['minDat','Approval history']
attr_dic['Color'][1]=                  ['webMin','Color']
attr_dic['Color'][2]=                  ['minDat','Colour']
attr_dic['Streak'][1]=                 ['webMin','Streak']
attr_dic['Streak'][2]=                 ['minDat','Streak']
attr_dic['Luster'][1]=                 ['webMin','Luster']
attr_dic['Luster'][2]=                 ['minDat','Lustre']
attr_dic['Transparency'][1]=           ['webMin','Diaphaneity']
attr_dic['Transparency'][2]=           ['minDat','Transparency']
attr_dic['Pleochroism Scale'][1]=      ['minDat','Pleochroism']
attr_dic['Pleochroism'][1]=            ['webMin','RL Pleochroism']
attr_dic['Pleochroism (x)'][1]=        ['webMin','Pleochroism (x)']
attr_dic['Pleochroism (y)'][1]=        ['webMin','Pleochroism (y)']
attr_dic['Pleochroism (z)'][1]=        ['webMin','Pleochroism (z)']
attr_dic['RL Color'][1]=               ['webMin','RL Color']
attr_dic['RL Color'][2]=               ['minDat','Colour in reflected light']
attr_dic['In UV Light'][1]=            ['minDat','In UV light']
attr_dic['RL Bireflectance'][1]=       ['webMin','RL Bireflectance']
attr_dic['Anisotrophism'][1]=          ['webMin','RL Anisotrophism']
attr_dic['Anisotrophism'][2]=          ['minDat','Anisotropism']
attr_dic['Dichroism (e)'][1]=          ['webMin','Dichroism (e)']
attr_dic['Dichroism (w)'][1]=          ['webMin','Dichroism (w)']
attr_dic['Reflectivity'][1]=           ['minDat','Reflectivity']
attr_dic['Density'][1]=                ['minDat','Density']
attr_dic['Density'][2]=                ['webMin','Density']
attr_dic['Molecular Weight'][1]=       ['webMin','Composition']
attr_dic['Electron Density'][1]=       ['webMin','Electron Density']
attr_dic['Hardness'][1]=               ['minDat','Hardness']
attr_dic['Hardness'][2]=               ['webMin','Hardness']
attr_dic['Crystal System'][1]=         ['webMin','Crystal System']
attr_dic['Crystal System'][2]=         ['minDat','Crystal System']
attr_dic['Specific Gravity'][1]=       ['minDat','Specific Gravity']
attr_dic['Fracture'][1]=               ['webMin','Fracture']
attr_dic['Fracture'][2]=               ['minDat','Fracture']
attr_dic['Dana Class'][1]=             ['webMin','Dana Class']
attr_dic['Dana 8th ed.'][1]=           ['minDat','Dana 8th ed.']
attr_dic['Dana 7th ed.'][1]=           ['minDat','Dana 7th ed.']
attr_dic['Strunz Class'][1]=           ['webMin','Strunz Class']
attr_dic['Strunz 10th ed.'][1]=        ['minDat','Nickel-Strunz 10th (pending) ed.']
attr_dic['Strunz 8th ed.'][1]=         ['minDat','Strunz 8th ed.']
attr_dic['Cell Dimensions'][1]=        ['webMin','Cell Dimensions']
attr_dic['Cell Dimensions'][2]=        ['minDat','Cell Parameters']
attr_dic['Habit'][1]=                  ['webMin','Habit']
attr_dic['Axial Ratios'][1]=           ['webMin','Axial Ratios']
attr_dic['Radioactivity'][1]=          ['webMin','Radioactivity']
attr_dic['Photoelectric'][1]=          ['webMin','Photoelectric']
attr_dic['Environment'][1]=            ['webMin','Environment']
attr_dic['Fermion Index'][1]=          ['webMin','Fermion Index']
attr_dic['Magnetism'][1]=              ['webMin','Magnetism']
attr_dic['Gladstone-Dale'][1]=         ['webMin','Gladstone-Dale']
attr_dic['X Ray Diffraction'][1]=      ['webMin','X Ray Diffraction']
attr_dic['Luminescence'][1]=           ['webMin','Luminescence']
attr_dic['Optical Data'][1]=           ['webMin','Optical Data']
attr_dic['Birefringence'][1]=          ['minDat','Birefringence']
attr_dic['Tenacity'][1]=               ['minDat','Tenacity']
attr_dic['Surface Relief'][1]=         ['minDat','Surface Relief']
attr_dic['Morphology'][1]=             ['minDat','Morphology']
attr_dic['Elements listed'][1]=        ['minDat','Elements listed']
attr_dic['Common Impurities'][1]=      ['minDat','Common Impurities']
attr_dic['Geological Setting'][1]=     ['minDat','Geological Setting']
attr_dic['Member of'][1]=              ['minDat','Member of']
attr_dic['Isostructural with'][1]=     ['minDat','Isostructural with']
attr_dic["Hey's CIM Ref."][1]=         ["minDat","Hey's CIM Ref."]
attr_dic['Type'][1]=                   ['minDat','Type']
attr_dic['Powder Diffraction Data'][1]=['minDat','Powder Diffraction Data']
attr_dic['Unit Cell V'][1]=            ['minDat','Unit Cell V']
attr_dic['Space Group'][1]=            ['minDat','Space Group']
attr_dic['Dispersion'][1]=             ['minDat','Dispersion']
attr_dic['RI values'][1]=              ['minDat','RI values']
attr_dic['Cleavage'][1]=               ['minDat','Cleavage']
attr_dic['Ratio'][1]=                  ['minDat','Ratio']
attr_dic['Type Locality'][1]=          ['minDat','Type Locality']
attr_dic['Co-Type Localities'][1]=     ['minDat','Co-Type Localities']
attr_dic['Class (H-M)'][1]=            ['minDat','Class (H-M)']
attr_dic['Health Risks'][1]=           ['minDat','Health Risks']
attr_dic['2V'][1]=                     ['minDat','2V']
attr_dic['Twinning'][1]=               ['minDat','Twinning']
attr_dic['Parting'][1]=                ['minDat','Parting']
attr_dic['Notes'][1]=                  ['minDat','Notes']
attr_dic['Mineral Dealers'][1]=        ['minDat','Mineral Dealers']

# %%
def get_atr_val(mnrl_web,mnrl_dat,atr):
    #m=''
    value =''
    for i in attr_dic[atr].keys():
        lst = attr_dic[atr][i]
        
        if lst[0] == 'webMin':
            try:
                value = webMin_dic[mnrl_web][lst[1]]
                #m = mnrl_web
                break
            except:
                a=1
        else:
            try:
                value = minDat_dic[mnrl_dat][lst[1]]
                #m = mnrl_dat
                break
            except:
                a=1
    return value

# %%
merged_dic  = defaultdict(lambda:defaultdict(str))

for mnrl in all_mnrl:
    mName_web = ''
    mName_dat = ''
    for m in webMin_dic.keys():
        if mnrl.lower() == m.lower():
            mName_web = m
            break
    
    for m in  minDat_dic.keys():
        if mnrl.lower() == m.lower():
            mName_dat = m
            break
    
    if mName_dat != '':
        m= mName_dat
        
    if mName_web != '':
        m= mName_web    
    
    for atr in attr_dic.keys():
        val = get_atr_val(mName_web,mName_dat, atr)
        if m != '':
            merged_dic[m][atr] = val

# %%
#for k in merged_dic.keys():
#    print (len(merged_dic[k].keys()))
print(len(merged_dic.keys())    )

mrg_set = set()
for m in merged_dic.keys():
    mrg_set.add(m.lower())
    
lst = all_mnrl - mrg_set
# Out:
# 9609

# %%
print(lst)
len(lst)
# Out:
# set()
# 0

# %%
with open('merged_webmin_mindat.json', 'w') as file:
    json.dump(merged_dic, file)

# %%
merged_dic.keys()
# Out:
# dict_keys(['Thomasclarkite-(Y)', 'Levyne-Ca', 'Ermakovite', 'Flinkite', 'Darlingite', 'Changbaiite', 'Nobleite', 'Ferro-actinolite', 'Lasionite', 'Zinc-bearing Cerussite', 'Parthéite', 'Gmelinite', 'Kayserite', 'β-Cristobalite', 'Native Sulphur', 'Crisocola', 'Fettelite', 'Aftalosa', 'Feather Alum', 'Kuramite', 'Killalaite', 'Chalcophane', 'Pirop', 'Perite', 'Babkinite', 'Hannayite', 'Beudantite', 'Thalheimite', 'Chrysocolle', 'Stringhamite', 'Magnesio-riebeckite', 'Clausthalie', 'Crestmoreite', 'Georgerobinsonite', 'Bavsiite', 'Anthoinite', 'Tuperssvatsiaite', 'Tungstenite (of Wells and Butler)', 'Ruthenium', 'Paraotwayite', 'Hydropyrolusite', 'Aquacreptite (of Harada)', 'Achtaryndit', 'Holtstamite', 'Ixionolite', "Venus' Hair Stone", 'Gartrellite', 'Dzierżanowskite', 'Johnbaumite-M', 'Miargyrite', 'Verdelite', 'Hendricksite', 'Epidote Manganèsifère', 'Stibiconite', 'IMA1999-030', 'Hauerite', 'Vonsenite', 'Borodaevite', 'Nickel Bloom', 'Siderochrome', 'Claudetite', 'Aleksandrovite', 'Lead-bearing Aragonite', 'Rancieite', 'Masonite', 'Sphärokobaltit', 'False Amethyst', 'Watatsumiite', 'Muckeite', 'Gauthierite', 'Barium-Nepheline', 'Diversilite-(Ce)', 'Manganotychite', 'Mckelveyite-(Nd)', 'Plata', 'Ronneburgite', 'Sphaerokobaltit', 'Brucite (of Gibbs)', 'Albiclase', 'Metathénardite', 'Petersite-(Ce)', 'Innsbruckite', 'Hemloite', 'Cupromolybdite', 'Queitite', 'Penwithite', 'Kamacite', 'Cinnamon Garnet', 'Lemoynite', 'Tarnovizite', 'Eitelite', 'Eisenglanz', 'Kenyaite', 'Levinsonite-(Y)', 'Fluorthalénite-(Y)', 'Serpierite', 'Disosmose', 'Thorosteenstrupine', 'Lead Glance', 'Barahonaite-(Al)', 'Scheelerz', 'Ilyukhinite', 'Brendelite', 'Dusmatovite', 'Omongwaite', 'Sarmientite', 'Chibaite', 'Alpersite', 'Marsturite', 'Horákite', 'Sidwillite', 'Aluminomagnesiohulsite', 'Martinite', 'Mesolite', 'Bustamite', 'Methane', 'Vanadiumdravite', 'Diallogite', 'Penikisite', 'Egyptian Blue', 'Luobusaite', 'Sabugalite', 'Bytownite', 'Ivanyukite-K', 'Kosmochlor', 'Ilsemannite', 'Ostranite', 'Stefanweissite', 'Morion', 'Gumucionite', 'Tripelglanz', 'Water Sapphire', 'Lead-parkerite', 'Vanackerite', 'Todorokite', 'Leonardsenite', 'Arrojadite', 'Saltonseaite', 'Otavite', 'Halochalzit', 'Bowieite', 'Manandonite', 'Tiragalloite', 'Dilithium', 'Fältspat', 'Jahnsite-(MnMnFe)', 'Magnesioriebeckite', 'Melonjosephite', 'Actynolin', 'Susannite', 'Halotrichit (of Hausmann)', 'Tinticite', 'Kashinite', 'IMA1996-045', 'Juabite', 'Kitaibelite', 'Castelnaudite', 'Siderogel', 'Antimonial Silver Blende', 'Plumbonacrite', 'Gorlandite', 'Stralite', 'Bismutocolumbite', 'Britholite-(Y)', 'Jadarite', 'Uranoanatase', 'Tourmalinite', 'Arsenquatrandorite', 'Ammonium-Stilbite', 'Bischofite (of Fischer)', 'Icosahedrite', 'Shepardite', 'Anyuiite', 'Apophyllite-(KF)', 'Gianellaite', 'Dioptase', 'Ameghinite', 'Kamotoite-(Y)', 'Qatranaite', 'Zirsinalite', 'Moëloite', 'Calc-clinobronzite', 'Farneseite', 'Låvenite', 'Pararealgar', 'Karystiolite', 'Zincolibethenite', 'Anemolite', 'Ramanite-(Cs)', 'Cobaltite', 'Apatite-(CaF)', 'Qitianglinite', 'Brattforsite', 'Zincovelesite-6N6S', 'Wölsendorfite', 'Glaucophane', 'Mawbyite', 'Ablykite', 'Tuxtlite', 'Nepheline', 'Iberite (of Svanberg)', 'Corundophilite', 'Chengdeite', 'Katsarosite', 'Cyanotrichite', 'Faizievite', 'Ramsbeckite', 'Smamite', 'Armenite (of Delamétherie)', 'Roggianite', 'Okermanite', 'Tincalconite', 'Stibi', 'Borocookeite', 'Oenite', 'Hendersonite', 'Hereroite', 'Yuksporite', 'Tugarinovite', 'Schneiderhohnite', 'Darrellhenryite', 'Kobyashevite', 'Zavaritskite', 'Mendozavilite-NaFe', 'Baroite', 'Biraite-(La)', 'Iozite', 'Potosíite', 'Or', 'Boromullite', 'Gotthardite', 'Thorolite', 'Moeloite', 'Naldretteite', 'Xanthitane', 'Pilawite-(Y)', 'Haapalaite', 'Sismondine', 'Tschaunerite', 'Hydroxycalciopyrochlore', 'Achirite', 'Prasolite', 'Indium', 'Riomarinaite', 'Pseudo-autunite', 'Henmilite', 'Dyscrasite', 'Gormanite', 'Zharchikhite', 'Finnemanite', 'Geerite', 'Baryto-Fluate of Lime', 'Yoderite', 'Mussite (of Bonvoisin)', 'Volta ...

# %%
keys = attr_dic.keys()
merged_dic2  = {key:{k:merged_dic[k][key] for k in merged_dic if key in merged_dic[k]} for key in keys}

df = pd.DataFrame(merged_dic2)
df
# Out:
#                          Synonym  \
# Thomasclarkite-(Y)   IMA1997-047
# Levyne-Ca              Echellite
# Ermakovite
# Flinkite              ICSD 16902
# Darlingite
# ...                          ...
# Bodieite
# Kurilite
# Agolite
# Viluite
# Macusanite
#
#                                                           Name Origin  \
# Thomasclarkite-(Y)   Named after Thomas Henry Clark (1893-1996), M...
# Levyne-Ca            Named for Armand Levy (1794-1841), French min...
# Ermakovite
# Flinkite             Named for Gustav Flink (1849-1931), Swedish m...
# Darlingite
# ...                                                               ...
# Bodieite            Named for the Bodie Hills volcanic field, in w...
# Kurilite                                      Named for the locality.
# Agolite
# Viluite
# Macusanite                                    Named for the locality.
#
#                                               Formula  \
# Thomasclarkite-(Y)   (Na,Ce)(Y,REE)(HCO3)(OH)3•4(H2O)
# Levyne-Ca                 (Ca,Na2,K2)Al2Si4O12•6(H2O)
# Ermakovite                            (NH4)(As2O3)2Br
# Flinkite                        Mn++2Mn+++(AsO4)(OH)4
# Darlingite                                       SiO2
# ...                                               ...
# Bodieite                              Bi2(TeO3)2(SO4)
# Kurilite                            (Ag,Au)2(Te,Se,S)
# Agolite
# Viluite
# Macusanite
#
#                                                Empirical Formula  \
# Thomasclarkite-(Y)        Na0.8Ce0.2Y0.5REE0.7(HCO3)(OH)3•4(H2O)
# Levyne-Ca            Ca2.73Na0.65K0.2Al6.31Si11.69O36•16.66(H2O)
# Ermakovite
# Flinkite                                    Mn2+2Mn3+(AsO4)(OH)4
# Darlingite
# ...                                                          ...
# Bodieite
# Kurilite                                Ag1.5Au0.5Te0.6Se0.3S0.1
# Agolite
# Viluite
# Macusanite
#
#                                             IMA Status Approval History  \
# Thomasclarkite-(Y)    Approved IMA 1998 (Dana # Added)
# Levyne-Ca            Valid Species 1997 (Pre-IMA) 1825
# Ermakovite               Approved, Pending publication
# Flinkite                  Valid Species (Pre-IMA) 1889
# Darlingite
# ...                                                ...              ...
# Bodieite                                      Approved
# Kurilite                          Discredited IMA 2006
# Agolite
# Viluite
# Macusanite
#
#                                                                 Color  Streak  \
# Thomasclarkite-(Y)                                     White, Yellow.   white
# Levyne-Ca            White, Grayish white, Reddish white, Yellowis...   white
# Ermakovite
# Flinkite                  Green, Greenish brown, Dark greenish brown.
# Darlingite
# ...                                                               ...     ...
# Bodieite                                  Colorless, yellow, or green   White
# Kurilite                                            Gray, Steel gray.   black
# Agolite
# Viluite
# Macusanite
#
#                                     Luster                 Transparency  ...  \
# Thomasclarkite-(Y)       Vitreous (Glassy)   Translucent to transparent  ...
# Levyne-Ca                Vitreous (Glassy)   Transparent to Translucent  ...
# Ermakovite                                                               ...
# Flinkite                  Vitreous, Greasy                  Transparent  ...
# Darlingite                                                               ...
# ...                                    ...                          ...  ...
# Bodieite            Sub-Adamantine, Greasy     Transparent, Translucent  ...
# Kurilite                          Metallic                       Opaque  ...
# Agolite                                                                  ...
# Viluite                                                                  ...
# Macusanite                                                               ...
#
#                                         Ratio  \
# Thomasclarkite-(Y)    a:b:c = 0.35 : 1 : 0.35
# Levyne-Ca
# Ermakovite
# Flinkite            a:b:c = 0.728 : 1 : 0.408
# Darlingite
# ...                                       ...
# Bodieite            a:b:c = 1.091 : 1 : 1.978
# Kurilite                      a:c = 1 : 1.241
# Agolite
# Viluite
# Macusanite
#
#                                                         Type Locality  \
# Thomasclarkite-(Y)  ⓘ Poudrette quarry (De-Mix quarry; Demix quarr...
# Levyne-Ca
# Ermakovite          ⓘ Ermakovite type locality, Ravat Kishlak, Ayn...
# Flinkite            ⓘ Harstigen Mine, Pajsberg, Persberg ore distr...
# Darlingite
# ...                                                               ...
# Bodieite
# Kurilite            ⓘ Prasolovskoe Au deposit (Prasolovka deposit)...
# Agolite
# Viluite
# Macusanite
#
#                                                    Co-Type Localities  \
# Thomasclarkite-(Y)
# Levyne-Ca
# Ermakovite
# Flinkite
# Darlingite
# ...                                                               ...
# Bodieite            ⓘ Pittsburg-Liberty Mine (Pittsburg claim; Pit...
# Kurilite
# Agolite
# Viluite
# Macusanite
#
#                                                       Class (H-M)  \
# Thomasclarkite-(Y)                                 2 - Sphenoidal
# Levyne-Ca
# Ermakovite          6/mmm (6/m 2/m 2/m) - Dihexagonal Dipyramidal
# Flinkite                          mmm (2/m 2/m 2/m) - Dipyramidal
# Darlingite
# ...                                                           ...
# Bodieite                                          2/m - Prismatic
# Kurilite                                         3 - Rhombohedral
# Agolite
# Viluite
# Macusanite
#
#                                                          Health Risks 2V  \
# Thomasclarkite-(Y)  No information on health risks for this materi...
# Levyne-Ca
# Ermakovite          No information on health risks for this materi...
# Flinkite            No information on health risks for this materi...
# Darlingite          No information on health risks for this materi...
# ...                                                               ... ..
# Bodieite            No information on health risks for this materi...
# Kurilite            No information on health risks for this materi...
# Agolite
# Viluite             No information on health risks for this materi...
# Macusanite
#
#                    Twinning Parting                          Notes  \
# Thomasclarkite-(Y)
# Levyne-Ca
# Ermakovite
# Flinkite                                           Soluble in HCl.
# Darlingite
# ...                     ...     ...                            ...
# Bodieite                             Readily soluble in dilute HCl
# Kurilite                       none
# Agolite
# Viluite
# Macusanite
#
#                                                       Mineral Dealers
# Thomasclarkite-(Y)  Quality Mineral Specimens For Sale ~ Cal Neva ...
# Levyne-Ca
# Ermakovite          Fine Minerals from Weinrich Minerals, Inc.Wile...
# Flinkite            Quality Minerals at Fair PricesBuy rare minera...
# Darlingite          Quality Minerals at Fair PricesFine Minerals f...
# ...                                                               ...
# Bodieite            Quality Minerals at Fair PricesFine Minerals f...
# Kurilite            Buy from David K Joyce mineralsBuy from McDoug...
# Agolite
# Viluite
# Macusanite
#
# [9609 rows x 74 columns]

# %%
df.to_csv('merged_webmin_mindat.csv')
